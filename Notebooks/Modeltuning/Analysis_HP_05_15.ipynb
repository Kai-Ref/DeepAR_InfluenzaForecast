# %%
import os
os.chdir('/home/reffert/DeepAR_InfluenzaForecast')
from PythonFiles.model import model, preprocessing, split_forecasts_by_week, \
forecast_by_week, train_test_split,update_deepAR_parameters, \
generate_model_results_by_hp_dict
from PythonFiles.PlottingFunctions import plot_coverage, print_forecasts_by_week, hyperparameter_boxplots, plot_model_results_by_hp, hp_color_plot
from PythonFiles.Configuration import Configuration
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from gluonts.mx import Trainer, DeepAREstimator
from gluonts.evaluation import make_evaluation_predictions, Evaluator
import ray
from ray.air import session
from ray import tune
import itertools
from gluonts.mx.distribution import NegativeBinomialOutput
config = Configuration()

# %%
df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Hyperparameter_results_15_05.csv", sep=',')

hp_search_space = {
    "num_cells": tune.grid_search([60, 140]),
    "num_layers": tune.grid_search([8, 10]),
    "context_length":tune.grid_search([2, 4, 8]),
    "cell_type":tune.grid_search(["lstm"]),
    "epochs":tune.grid_search([40, 60, 80]),
    "use_feat_static_real":tune.grid_search([True, False]),
    "use_feat_dynamic_real":tune.grid_search([True]),
    "use_feat_static_cat":tune.grid_search([False, True]),
    #"cardinality":tune.sample_from(lambda spec:[2]*411 if spec.config.use_feat_static_cat else None),
}

model_results_by_hp, overall_df = generate_model_results_by_hp_dict(df, hp_search_space)
# Out:
# 408
# There are combinations with fewer modelRuns!!
#                            total_modelruns  independent_combinations
# modelruns_per_combination
# 3.0                                    348                     116.0
# 2.0                                     52                      26.0
# 4.0                                      8                       2.0

# %%
plot_model_results_by_hp(config, model_results_by_hp, hp_search_space, number_of_plots=40, col="mean_WIS",figsize=(16, 9), overall_df=overall_df, sort_by="model_WIS_median", plottype="best", plot = "bp")

# %%
'''
col: "mean_WIS", "time_this_iter_s"
sort_by: "mean_WIS", "time_this_iter_s", "model_WIS_mean", "model_WIS_variance", "model_WIS_sd", "model_WIS_median", "model_time_mean", "model_time_variance", "model_time_sd",\
         "model_time_median"(, "shape") 
plottype: "unordered"(not ordered), "best" or "worst"
'''
plot_model_results_by_hp(config, model_results_by_hp, hp_search_space, number_of_plots=40, col="mean_WIS",figsize=(16, 9), overall_df=overall_df, sort_by="model_WIS_median", plottype="best", plot = "scatter")

# %%
added_cols = ["model_WIS_mean", "model_WIS_variance", "model_WIS_sd", "model_WIS_median", "model_time_mean", "model_time_variance", "model_time_sd",\
         "model_time_median", "shape"] 
display(overall_df.sort_values("model_WIS_mean")[added_cols+[col for col in df.columns if ("config" in col)&("cardinality" not in col)]].drop_duplicates().head(20))
# Out:
#      model_WIS_mean  model_WIS_variance  model_WIS_sd  model_WIS_median  \
# 369      353.904818          538.635779     23.208528        343.481900
# 377      359.993085         1371.655148     37.035863        342.837765
# 373      365.095499          421.850153     20.538991        372.100591
# 87       369.778389          168.976250     12.999087        368.705670
# 372      371.805984         1051.012690     32.419326        379.552842
# 240      372.710682          531.782011     23.060399        383.672467
# 396      375.036573           64.187875      8.011734        372.785558
# 140      375.353511           20.337046      4.509661        375.353511
# 279      375.576666           10.402138      3.225235        375.576666
# 100      376.003237          578.534275     24.052739        377.376829
# 389      378.390395          292.360831     17.098562        375.538382
# 116      379.406193         1169.638705     34.199981        393.898149
# 276      380.093557            0.689608      0.830426        380.093557
# 143      381.172988           76.181535      8.728203        381.172988
# 273      381.422191          265.671781     16.299441        381.422191
# 223      382.319543         1613.178744     40.164396        389.801751
# 125      382.452457           41.227074      6.420831        382.452457
# 117      382.808749           82.033647      9.057243        378.682760
# 374      384.172657          729.896209     27.016591        392.120538
# 390      384.491108         1642.944748     40.533255        366.220221
#
#      model_time_mean  model_time_variance  model_time_sd  model_time_median  \
# 369      6103.897740         31219.665348     176.690875        6013.249428
# 377      3915.358529         32240.505170     179.556412        3891.109677
# 373      7238.603882         31243.197945     176.757455        7191.290450
# 87       6707.702162        136611.168147     369.609481        6903.313550
# 372      6826.513456        104295.057437     322.947453        6842.736548
# 240      4694.712696         27360.085310     165.408843        4705.996361
# 396      4081.417745         16215.947498     127.341853        4020.038193
# 140      7555.711132         25794.369382     160.606256        7555.711132
# 279      6205.481035         75149.830607     274.134694        6205.481035
# 100      6072.392302        156091.024923     395.083567        6003.424447
# 389      7646.558644         53935.743817     232.240702        7743.105304
# 116      5107.727401         53223.773328     230.702781        5207.172515
# 276      5022.436353         17320.333835     131.606739        5022.436353
# 143      9190.592564            32.894650       5.735386        9190.592564
# 273      4152.778806         56922.822940     238.585043        4152.778806
# 223      4454.364927         22516.232983     150.054100        4484.508260
# 125      7666.842370          8308.652920      91.151812        7666.842370
# 117      5390.036209        129424.231680     359.755795        5510.016277
# 374      3108.526194          3651.761307      60.429805        3112.258629
# 390      7583.113772         34764.368742     186.452055        7529.637347
#
#      shape config/cell_type  config/context_length  config/epochs  \
# 369    3.0             lstm                      4             60
# 377    3.0             lstm                      2             60
# 373    3.0             lstm                      8             80
# 87     3.0             lstm                      2             80
# 372    3.0             lstm                      4             80
# 240    3.0             lstm                      2             80
# 396    3.0             lstm                      4             60
# 140    2.0             lstm                      8             60
# 279    2.0             lstm                      2             40
# 100    3.0             lstm                      4             40
# 389    3.0             lstm                      2             80
# 116    3.0             lstm                      8             80
# 276    2.0             lstm                      2             80
# 143    2.0             lstm                      8             80
# 273    2.0             lstm                      2             60
# 223    3.0             lstm                      4             80
# 125    2.0             lstm                      8             80
# 117    3.0             lstm                      2             40
# 374    3.0             lstm                      2             40
# 390    3.0             lstm                      4             80
#
#      config/num_cells  config/num_layers  config/use_feat_dynamic_real  \
# 369               140                  8                          True
# 377                60                 10                          True
# 373               140                  8                          True
# 87                140                  8                          True
# 372               140                  8                          True
# 240                60                 10                          True
# 396                60                  8                          True
# 140               140                 10                          True
# 279               140                 10                          True
# 100               140                 10                          True
# 389               140                 10                          True
# 116                60                  8                          True
# 276                60                 10                          True
# 143               140                 10                          True
# 273                60                 10                          True
# 223                60                  8                          True
# 125               140                  8                          True
# 117               140                  8                          True
# 374                60                 10                          True
# 390               140                 10                          True
#
#      config/use_feat_static_cat  config/use_feat_static_real
# 369                       False                        False
# 377                       False                        False
# 373                       False                        False
# 87                        False                        False
# 372                       False                        False
# 240                       False                        False
# 396                        True                        False
# 140                        True                        False
# 279                        True                        False
# 100                       False                        False
# 389                       False                        False
# 116                        True                        False
# 276                        True                        False
# 143                        True                        False
# 273                        True                        False
# 223                       False                        False
# 125                        True                        False
# 117                        True                        False
# 374                       False                        False
# 390                       False                        False

# %%
unique_df = overall_df[added_cols+[col for col in df.columns if ("config" in col)&("cardinality" not in col)]].drop_duplicates()
print(len(unique_df))
print(len(overall_df))
hyperparameter_boxplots(unique_df, hp_search_space, col="model_WIS_variance")
print("________________")
hyperparameter_boxplots(unique_df, hp_search_space, col="model_WIS_mean")
# Out:
# 144
# 408
# ________________

# %%
hp_color_plot(config, overall_df, hp_search_space)

# %%
hp_color_plot(config, overall_df, hp_search_space, x_axis="model_WIS_median", y_axis="model_time_mean")
