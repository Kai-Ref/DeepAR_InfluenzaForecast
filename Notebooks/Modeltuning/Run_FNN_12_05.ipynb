# %%
import os
os.chdir('/home/reffert/DeepAR_InfluenzaForecast')
from PythonFiles.model import model, preprocessing, split_forecasts_by_week, plot_coverage, print_forecasts_by_week, forecast_by_week, train_test_split, update_deepAR_parameters
from PythonFiles.Configuration import Configuration
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from gluonts.model.simple_feedforward import SimpleFeedForwardEstimator
from gluonts.mx import Trainer
from gluonts.evaluation import make_evaluation_predictions
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.rolling_dataset import generate_rolling_dataset,StepStrategy
from gluonts.evaluation import make_evaluation_predictions, Evaluator
import ray
from ray.air import session
from ray import tune
from gluonts.mx.distribution import NegativeBinomialOutput
config = Configuration()
influenza_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/influenza.csv", sep=',')
population_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/PopulationVector.csv", sep=',')
neighbourhood_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/AdjacentMatrix.csv", sep=',', index_col=0)

config.train_start_time = datetime(1999,1,1,0,0,0)#datetime(2010,1,1,0,0,0)
config.train_end_time = datetime(2016,9,30,23,0,0)
config.test_end_time = datetime(2018,9,30,23,0,0)
overall_evaluation_df = pd.DataFrame()

data_splits_dict = {}
output_dict = {}

locations = list(influenza_df.location.unique())
#Process the df into a uniformly spaced df
df = influenza_df.loc[influenza_df.location.isin(locations), ['value', 'location', 'date','week']]
df = preprocessing(config, df, check_count=False, output_type="corrected_df")
for location in locations:
    df.loc[df.location == location, "population"] = int(population_df.loc[population_df.Location == location, "2011"].values[0])
    df.loc[df.location == location, locations] = neighbourhood_df.loc[neighbourhood_df.index==location,locations].values[0].astype(int)
    
# Data split with no additional features and training start in 2010
#data_splits_dict["without_features_2001"] = list(train_test_split(config, df, False))
data_splits_dict["with_features_2001"] = list(train_test_split(config, df, True))

# Change the beginning of the training period
#config.train_start_time = datetime(2010,1,1,0,0,0)
#data_splits_dict["without_features_2010"] = list(train_test_split(config, df, False))
#data_splits_dict["with_features_2010"] = list(train_test_split(config, df, True))
# Out:
# /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/gluonts/model/simple_feedforward/__init__.py:18: FutureWarning: The module gluonts.model.simple_feedforward has been moved to gluonts.mx.model.simple_feedforward. In GluonTS v0.12 it will be no longer possible to use the old path. Try to use 'from gluonts.mx import SimpleFeedForwardEstimator'.
#   warnings.warn(

# %%
def update_FNN_parameters(config, new_parameters):
    ''' 
    This function updates the DeepAR-configuration in the Configuration.py file. 
    Note that new_parameters must be a dict containing the exact keys used in config.parameters.
    '''
    parameters = config.fnnparameters.copy()
    for key in new_parameters.keys():
        if key in parameters.keys():
            parameters[key] = new_parameters[key]
        else:
            print(f"This key {key} isn't available in config.parameters! Thus the default config will maintain.")

    fnnestimator = SimpleFeedForwardEstimator(num_hidden_dimensions=parameters["num_hidden_dimensions"],
                                              prediction_length=parameters["prediction_length"],
                                              context_length=parameters["context_length"],
                                              distr_output=parameters["distr_output"],
                                              batch_size=parameters["batch_size"],
                                              batch_normalization=parameters["batch_normalization"],
                                              trainer=Trainer(epochs=parameters["epochs"],
                                                              num_batches_per_epoch=parameters["num_batches_per_epoch"],
                                                             ),
                                              )
    return fnnestimator

def evaluate(config, train, test, configuration):
    
    fnnestimator = update_FNN_parameters(configuration, config)
    
    predictor = fnnestimator.train(train)
    
    forecast_it, ts_it = make_evaluation_predictions(dataset=test, predictor=predictor,num_samples=100)
    forecasts = list(forecast_it)
    tss = list(ts_it)
    
    # Evaluation with the quantiles of the configuration and calculation of the mean_WIS
    evaluator = Evaluator(quantiles=configuration.quantiles)    
    agg_metrics = evaluator(tss, forecasts)[0]
    mean_WIS = agg_metrics["mean_absolute_QuantileLoss"]/(config["prediction_length"]*411)
    return mean_WIS

def objectiveFNN(config, train, test, configuration):
    score = evaluate(config, train, test, configuration)
    session.report({"mean_WIS":score})

# %%
hp_search_space = {
    "num_hidden_dimensions": tune.grid_search([[5],[10], [20]]),
    "context_length":tune.grid_search([4, 52, 104]),
    "epochs":tune.grid_search([5, 10, 20]),
    "prediction_length" : tune.grid_search([4, 52, 104]), 
    "num_batches_per_epoch":tune.grid_search([25, 50, 100]),
    "batch_normalization":tune.grid_search([True, False]),
    "batch_size":tune.grid_search([20, 32, 64]),
    }




train = data_splits_dict["with_features_2001"][0]
test = data_splits_dict["with_features_2001"][1]
configuration = Configuration()

tuner = tune.Tuner(
    tune.with_parameters(objectiveFNN, train=train, test=test, configuration=configuration),
    tune_config=tune.TuneConfig(
        num_samples = 5,
        metric="mean_WIS",
        mode="min",
        max_concurrent_trials=8,
    ),
    param_space=hp_search_space,
)
results = tuner.fit()

print("Best hyperparameters found were: ", results.get_best_result().config)

results_df = results.get_dataframe()
print(results_df)
results_df.to_csv("FNN_Hyperparameter_results_15_05.csv")
# Out:
# 2023-05-15 08:37:52,845	INFO worker.py:1553 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-15 10:04:29</td></tr>
# <tr><td>Running for: </td><td>01:26:28.76        </td></tr>
# <tr><td>Memory:      </td><td>62.2/236.0 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 8.0/48 CPUs, 0/0 GPUs, 0.0/144.3 GiB heap, 0.0/65.84 GiB objects
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 90 more trials not shown (90 TERMINATED)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc                 </th><th>batch_normalization  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  context_length</th><th style="text-align: right;">  epochs</th><th style="text-align: right;">    num_batches_per_epoc
# h</th><th>num_hidden_dimension
# s    </th><th style="text-align: right;">  prediction_length</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  mean_WIS</th></tr>
# </thead>
# <tbody>
# <tr><td>objectiveFNN_07888_00100</td><td>RUNNING   </td><td>172.22.1.197:3099262</td><td>True                 </td><td style="text-align: right;">          64</td><td style="text-align: right;">              52</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00101</td><td>RUNNING   </td><td>172.22.1.197:3099061</td><td>False                </td><td style="text-align: right;">          64</td><td style="text-align: right;">              52</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00104</td><td>RUNNING   </td><td>172.22.1.197:3099268</td><td>True                 </td><td style="text-align: right;">          32</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00105</td><td>RUNNING   </td><td>172.22.1.197:3099264</td><td>False                </td><td style="text-align: right;">          32</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00106</td><td>RUNNING   </td><td>172.22.1.197:3099272</td><td>True                 </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00107</td><td>RUNNING   </td><td>172.22.1.197:3099266</td><td>False                </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;"> 50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00108</td><td>RUNNING   </td><td>172.22.1.197:3099260</td><td>True                 </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;">100</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00109</td><td>RUNNING   </td><td>172.22.1.197:3099270</td><td>False                </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;">100</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_07888_00000</td><td>TERMINATED</td><td>172.22.1.197:3099061</td><td>True                 </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;"> 25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         129.29 </td><td style="text-align: right;">   723.72 </td></tr>
# <tr><td>objectiveFNN_07888_00001</td><td>TERMINATED</td><td>172.22.1.197:3099260</td><td>False                </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;"> 25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         117.361</td><td style="text-align: right;">   734.446</td></tr>
# <tr><td>objectiveFNN_07888_00002</td><td>TERMINATED</td><td>172.22.1.197:3099262</td><td>True                 </td><td style="text-align: right;">          32</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;"> 25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         164.928</td><td style="text-align: right;">   768.128</td></tr>
# <tr><td>objectiveFNN_07888_00003</td><td>TERMINATED</td><td>172.22.1.197:3099264</td><td>False                </td><td style="text-align: right;">          32</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;"> 25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         171.071</td><td style="text-align: right;">   754.526</td></tr>
# <tr><td>objectiveFNN_07888_00004</td><td>TERMINATED</td><td>172.22.1.197:3
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  44%|████▍     | 11/25 [00:10<00:13,  1.04it/s, epoch=1/5, avg_epoch_loss=2.06]
#  32%|███▏      | 8/25 [00:10<00:21,  1.25s/it, epoch=1/5, avg_epoch_loss=1.41]
#  52%|█████▏    | 13/25 [00:10<00:09,  1.22it/s, epoch=1/5, avg_epoch_loss=1.29]
#  52%|█████▏    | 13/25 [00:10<00:09,  1.28it/s, epoch=1/5, avg_epoch_loss=3.38]
#  56%|█████▌    | 14/25 [00:10<00:08,  1.31it/s, epoch=1/5, avg_epoch_loss=2.86]
#  36%|███▌      | 9/25 [00:11<00:19,  1.22s/it, epoch=1/5, avg_epoch_loss=1.63]
#  20%|██        | 5/25 [00:11<00:45,  2.27s/it, epoch=1/5, avg_epoch_loss=1.86]
#  16%|█▌        | 4/25 [00:11<01:00,  2.87s/it, epoch=1/5, avg_epoch_loss=1.21]
# 100%|██████████| 25/25 [00:18<00:00,  1.33it/s, epoch=1/5, avg_epoch_loss=1.69]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:16<00:00,  1.48it/s, epoch=1/5, avg_epoch_loss=2.9]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:17<00:00,  1.45it/s, epoch=1/5, avg_epoch_loss=3.57]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:17<00:00,  1.39it/s, epoch=1/5, avg_epoch_loss=1.35]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  84%|████████▍ | 21/25 [00:20<00:03,  1.08it/s, epoch=1/5, avg_epoch_loss=1.33]
#  96%|█████████▌| 24/25 [00:21<00:00,  1.19it/s, epoch=1/5, avg_epoch_loss=1.45]
# 100%|██████████| 25/25 [00:21<00:00,  1.14it/s, epoch=1/5, avg_epoch_loss=1.44]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:22<00:00,  1.12it/s, epoch=1/5, avg_epoch_loss=1.3]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  52%|█████▏    | 13/25 [00:22<00:19,  1.66s/it, epoch=1/5, avg_epoch_loss=1.56]
#  44%|████▍     | 11/25 [00:22<00:27,  1.94s/it, epoch=1/5, avg_epoch_loss=1.6]
# 100%|██████████| 25/25 [00:08<00:00,  2.85it/s, epoch=2/5, avg_epoch_loss=1.35]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  2.90it/s, epoch=2/5, avg_epoch_loss=2.73]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  2.95it/s, epoch=2/5, avg_epoch_loss=3.01]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:09<00:00,  2.69it/s, epoch=2/5, avg_epoch_loss=1.39]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  80%|████████  | 20/25 [00:10<00:02,  1.98it/s, epoch=2/5, avg_epoch_loss=1.01]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.67it/s, epoch=2/5, avg_epoch_loss=1.7]
# 100%|██████████| 25/25 [00:09<00:00,  2.77it/s, epoch=3/5, avg_epoch_loss=1.26]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  80%|████████  | 20/25 [00:32<00:07,  1.48s/it, epoch=1/5, avg_epoch_loss=1.55]
# 100%|██████████| 25/25 [00:07<00:00,  3.29it/s, epoch=3/5, avg_epoch_loss=2.19]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  92%|█████████▏| 23/25 [00:33<00:02,  1.35s/it, epoch=1/5, avg_epoch_loss=1.62]
# 100%|██████████| 25/25 [00:12<00:00,  1.98it/s, epoch=2/5, avg_epoch_loss=1.05]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  2.83it/s, epoch=3/5, avg_epoch_loss=2.43]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  2.96it/s, epoch=3/5, avg_epoch_loss=1.76]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:35<00:00,  1.41s/it, epoch=1/5, avg_epoch_loss=1.68]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:14<00:00,  1.71it/s, epoch=2/5, avg_epoch_loss=1.7]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:37<00:00,  1.51s/it, epoch=1/5, avg_epoch_loss=1.57]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:07<00:00,  3.15it/s, epoch=4/5, avg_epoch_loss=1.33]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  3.01it/s, epoch=4/5, avg_epoch_loss=2.12]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:09<00:00,  2.71it/s, epoch=4/5, avg_epoch_loss=1.81]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  2.89it/s, epoch=4/5, avg_epoch_loss=1.6]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.88it/s, epoch=3/5, avg_epoch_loss=1.32]
#  40%|████      | 10/25 [00:10<00:16,  1.09s/it, epoch=2/5, avg_epoch_loss=1.34]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.85it/s, epoch=3/5, avg_epoch_loss=1.39]
# 100%|██████████| 25/25 [00:13<00:00,  1.88it/s, epoch=3/5, avg_epoch_loss=1.29]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:18,  1.14s/it, epoch=2/5, avg_epoch_loss=1.51]
# 100%|██████████| 25/25 [00:08<00:00,  3.01it/s, epoch=5/5, avg_epoch_loss=1.48]
# 100%|██████████| 25/25 [00:08<00:00,  2.99it/s, epoch=5/5, avg_epoch_loss=1.6]
# 100%|██████████| 25/25 [00:13<00:00,  1.80it/s, epoch=3/5, avg_epoch_loss=1.25]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:08<00:00,  3.08it/s, epoch=5/5, avg_epoch_loss=1.45]
# 100%|██████████| 25/25 [00:08<00:00,  3.00it/s, epoch=5/5, avg_epoch_loss=1.48]
#  80%|████████  | 20/25 [00:21<00:05,  1.08s/it, epoch=2/5, avg_epoch_loss=1.51]
#  72%|███████▏  | 18/25 [00:10<00:04,  1.72it/s, epoch=4/5, avg_epoch_loss=1.42]
#  72%|███████▏  | 18/25 [00:20<00:07,  1.14s/it, epoch=2/5, avg_epoch_loss=1.47]
#  80%|████████  | 20/25 [00:10<00:02,  1.92it/s, epoch=4/5, avg_epoch_loss=1.74]
# 100%|██████████| 25/25 [00:26<00:00,  1.08s/it, epoch=2/5, avg_epoch_loss=1.43]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:14<00:00,  1.69it/s, epoch=4/5, avg_epoch_loss=1.33]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:13<00:00,  1.92it/s, epoch=4/5, avg_epoch_loss=1.67]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:28<00:00,  1.15s/it, epoch=2/5, avg_epoch_loss=1.51]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:18,  1.13s/it, epoch=3/5, avg_epoch_loss=1.52]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.85it/s, epoch=5/5, avg_epoch_loss=1.12]
# Running evaluation: 0it [00:00, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.80it/s, epoch=5/5, avg_epoch_loss=1.35]
# Running evaluation: 41922it [00:01, 25796.56it/s]
# Running evaluation: 0it [00:00, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:18,  1.14s/it, epoch=3/5, avg_epoch_loss=1.45]
# Running evaluation: 0it [00:00, ?it/s]m
# Running evaluation: 41922it [00:01, 22176.31it/s]
# Running evaluation: 41922it [00:02, 19535.03it/s]
# 100%|██████████| 25/25 [00:17<00:00,  1.47it/s, epoch=5/5, avg_epoch_loss=1.1]
# Running evaluation: 0it [00:00, ?it/s]m
# 100%|██████████| 25/25 [00:24<00:00,  1.00it/s, epoch=5/5, avg_epoch_loss=1.3]
#  36%|███▌      | 9/25 [00:27<00:18,  1.13s/it, epoch=3/5, avg_epoch_loss=1.53]
#  36%|███▌      | 9/25 [00:23<00:18,  1.14s/it, epoch=3/5, avg_epoch_loss=1.49]
# Running evaluation: 41922it [00:08, 4793.69it/s]
#  68%|██████▊   | 17/25 [00:30<00:15,  1.92s/it, epoch=3/5, avg_epoch_loss=1.52]
#  52%|█████▏    | 13/25 [00:26<00:27,  2.25s/it, epoch=3/5, avg_epoch_loss=1.46]
#  68%|██████▊   | 17/25 [00:47<00:15,  1.92s/it, epoch=3/5, avg_epoch_loss=1.52]
#  52%|█████▏    | 13/25 [00:43<00:27,  2.25s/it, epoch=3/5, avg_epoch_loss=1.46]
#  64%|██████▍   | 16/25 [00:44<00:30,  3.33s/it, epoch=3/5, avg_epoch_loss=1.43]
#  84%|████████▍ | 21/25 [00:51<00:11,  2.85s/it, epoch=3/5, avg_epoch_loss=1.5]
# (objectiveFNN pid=3099260) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099260)   return arr.astype(dtype, copy=True)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name              </th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>experiment_tag                                                                                                                               </th><th>hostname      </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">  mean_WIS</th><th>node_ip     </th><th style="text-align: right;">    pid</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th style="text-align: right;">   trial_id</th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>objectiveFNN_07888_00000</td><td>2023-05-15_08-40-13</td><td>True  </td><td>                </td><td>dcb02b9c51ad4282ae036e453da1cfc4</td><td>0_batch_normalization=True,batch_size=20,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4      </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   723.72 </td><td>172.22.1.197</td><td style="text-align: right;">3099061</td><td style="text-align: right;">             129.29 </td><td style="text-align: right;">           129.29 </td><td style="text-align: right;">       129.29 </td><td style="text-align: right;"> 1684132813</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00000</td><td style="text-align: right;">   0.00727654</td></tr>
# <tr><td>objectiveFNN_07888_00001</td><td>2023-05-15_08-40-06</td><td>True  </td><td>                </td><td>b49d4aac74924e7c9a6a5aa187ef3f88</td><td>1_batch_normalization=False,batch_size=20,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   734.446</td><td>172.22.1.197</td><td style="text-align: right;">3099260</td><td style="text-align: right;">             117.361</td><td style="text-align: right;">           117.361</td><td style="text-align: right;">       117.361</td><td style="text-align: right;"> 1684132806</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00001</td><td style="text-align: right;">   0.00570297</td></tr>
# <tr><td>objectiveFNN_07888_00002</td><td>2023-05-15_08-40-54</td><td>True  </td><td>                </td><td>a41809fbf41d4bc6bd6cbdfaf756c97e</td><td>2_batch_normalization=True,batch_size=32,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4      </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   768.128</td><td>172.22.1.197</td><td style="text-align: right;">3099262</td><td style="text-align: right;">             164.928</td><td style="text-align: right;">           164.928</td><td style="text-align: right;">       164.928</td><td style="text-align: right;"> 1684132854</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00002</td><td style="text-align: right;">   0.00533438</td></tr>
# <tr><td>objectiveFNN_07888_00003</td><td>2023-05-15_08-41-00</td><td>True  </td><td>                </td><td>f8c897c29f534d21bc292b01cdea9aa5</td><td>3_batch_normalization=False,batch_size=32,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   754.526</td><td>172.22.1.197</td><td style="text-align: right;">3099264</td><td style="text-align: right;">             171.071</td><td style="text-align: right;">           171.071</td><td style="text-align: right;">       171.071</td><td style="text-align: right;"> 1684132860</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00003</td><td style="text-align: right;">   0.00530243</td></tr>
# <tr><td>objectiveFNN_07888_00004</td><td>2023-05-15_08-42-28</td><td>True  </td><td>                </td><td>7b5a5cc7eabc4a12ae63603d196a6fcd</td><td>4_batch_normalization=True,batch_size=64,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4      </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   773.727</td><td>172.22.1.197</td><td style="text-align: right;">3099266</td><td style="text-align: right;">             259.058</td><td style="text-align: right;">           259.058</td><td style="text-align: right;">       259.058</td><td style="text-align: right;"> 1684132948</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00004</td><td style="text-align: right;">   0.0058465 </td></tr>
# <tr><td>objectiveFNN_07888_00005</td><td>2023-05-15_08-42-17</td><td>True  </td><td>                </td><td>3102a4e228264305b8bd8dffd9903040</td><td>5_batch_normalization=False,batch_size=64,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   764.653</td><td>172.22.1.197</td><td style="text-align: right;">3099268</td><td style="text-align: right;">             248.149</td><td style="text-align: right;">           248.149</td><td style="text-align: right;">       248.149</td><td style="text-align: right;"> 1684132937</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00005</td><td style="text-align: right;">   0.00515771</td></tr>
# <tr><td>objectiveFNN_07888_00006</td><td>2023-05-15_08-40-13</td><td>True  </td><td>                </td><td>a880be4acce1434fbd53b7aa8b9d74a6</td><td>6_batch_normalization=True,batch_size=20,context_length=52,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   705.844</td><td>172.22.1.197</td><td style="text-align: right;">3099270</td><td style="text-align: right;">             124.431</td><td style="text-align: right;">           124.431</td><td style="text-align: right;">       124.431</td><td style="text-align: right;"> 1684132813</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td style="text-align: right;">07888_00006</td><td style="text-align: right;">   0.00559187</td></tr>
# <tr><td>objectiveFNN_07888_00007</td><td>2023-05-15_08-40-21</td><td>True  </td><td>                </td><td>be10275c4cb44cdeaadbe1682a31e892</td><td>7_batch_normalization=False,batch_size=20,context_length=52,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4    </td><td>econ-stat-rr01</td><td style="text-align: right;">
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:54<00:20,  3.40s/it, epoch=3/5, avg_epoch_loss=1.44]
# (objectiveFNN pid=3099270) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099270)   return arr.astype(dtype, copy=True)
# (objectiveFNN pid=3099061) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099061)   return arr.astype(dtype, copy=True)
# 100%|██████████| 25/25 [01:02<00:00,  2.49s/it, epoch=3/5, avg_epoch_loss=1.47]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  20%|██        | 5/25 [00:10<00:42,  2.11s/it, epoch=1/5, avg_epoch_loss=4.58]
# (objectiveFNN pid=3099272) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099272)   return arr.astype(dtype, copy=True)
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [01:05<00:00,  2.64s/it, epoch=3/5, avg_epoch_loss=1.37]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  24%|██▍       | 6/25 [00:10<00:31,  1.68s/it, epoch=1/5, avg_epoch_loss=3.82]
#  28%|██▊       | 7/25 [00:11<00:28,  1.58s/it, epoch=4/5, avg_epoch_loss=1.15]
# Running evaluation: 0it [00:00, ?it/s]m
# Running evaluation: 41922it [00:01, 23239.91it/s]
#  16%|█▌        | 4/25 [00:11<01:02,  2.98s/it, epoch=1/5, avg_epoch_loss=4.27]
# Running evaluation: 0it [00:00, ?it/s]m
#  52%|█████▏    | 13/25 [00:20<00:18,  1.52s/it, epoch=1/5, avg_epoch_loss=4.5]
# Running evaluation: 41922it [00:04, 8771.43it/s]
#  16%|█▌        | 4/25 [00:11<00:59,  2.82s/it, epoch=1/5, avg_epoch_loss=4.36]
#  48%|████▊     | 12/25 [00:20<00:22,  1.71s/it, epoch=1/5, avg_epoch_loss=3.29]
#  32%|███▏      | 8/25 [00:12<00:27,  1.60s/it, epoch=4/5, avg_epoch_loss=1.49]
#  56%|█████▌    | 14/25 [00:23<00:18,  1.72s/it, epoch=4/5, avg_epoch_loss=1.3]
#  84%|████████▍ | 21/25 [00:31<00:05,  1.41s/it, epoch=1/5, avg_epoch_loss=4.28]
#  76%|███████▌  | 19/25 [00:30<00:09,  1.57s/it, epoch=1/5, avg_epoch_loss=2.88]
# 100%|██████████| 25/25 [00:37<00:00,  1.51s/it, epoch=1/5, avg_epoch_loss=3.86]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  16%|█▌        | 4/25 [00:32<01:02,  2.98s/it, epoch=1/5, avg_epoch_loss=4.13]
#  28%|██▊       | 7/25 [00:33<01:34,  5.24s/it, epoch=1/5, avg_epoch_loss=3.98]
#  56%|█████▌    | 14/25 [00:35<00:18,  1.72s/it, epoch=4/5, avg_epoch_loss=1.33]
#  32%|███▏      | 8/25 [00:27<00:27,  1.60s/it, epoch=4/5, avg_epoch_loss=1.46]
#  16%|█▌        | 4/25 [00:28<00:59,  2.82s/it, epoch=1/5, avg_epoch_loss=4.63]
#  76%|███████▌  | 19/25 [00:36<00:12,  2.06s/it, epoch=4/5, avg_epoch_loss=1.31]
#  60%|██████    | 15/25 [00:29<00:20,  2.02s/it, epoch=4/5, avg_epoch_loss=1.45]
# (objectiveFNN pid=3099262) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099262)   return arr.astype(dtype, copy=True)
# 100%|██████████| 25/25 [00:37<00:00,  1.51s/it, epoch=1/5, avg_epoch_loss=2.89]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  28%|██▊       | 7/25 [00:33<01:32,  5.16s/it, epoch=1/5, avg_epoch_loss=4.75]
#  36%|███▌      | 9/25 [00:10<00:18,  1.13s/it, epoch=2/5, avg_epoch_loss=2.96]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# (objectiveFNN pid=3099264) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099264)   return arr.astype(dtype, copy=True)
#  48%|████▊     | 12/25 [00:44<00:45,  3.49s/it, epoch=1/5, avg_epoch_loss=3.92]
# 100%|██████████| 25/25 [00:46<00:00,  1.85s/it, epoch=4/5, avg_epoch_loss=1.34]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  88%|████████▊ | 22/25 [00:39<00:05,  1.79s/it, epoch=4/5, avg_epoch_loss=1.37]
#  56%|█████▌    | 14/25 [00:10<00:07,  1.39it/s, epoch=2/5, avg_epoch_loss=2.92]
# 100%|██████████| 25/25 [00:19<00:00,  1.26it/s, epoch=2/5, avg_epoch_loss=2.86]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:43<00:00,  1.73s/it, epoch=4/5, avg_epoch_loss=1.48]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  64%|██████▍   | 16/25 [00:44<00:22,  2.45s/it, epoch=1/5, avg_epoch_loss=3.78]
#  56%|█████▌    | 14/25 [00:10<00:08,  1.30it/s, epoch=1/5, avg_epoch_loss=5.46]
# 100%|██████████| 25/25 [00:15<00:00,  1.59it/s, epoch=2/5, avg_epoch_loss=2.8]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:18,  1.14s/it, epoch=5/5, avg_epoch_loss=1.46]
#  88%|████████▊ | 22/25 [00:55<00:06,  2.02s/it, epoch=1/5, avg_epoch_loss=3.33]
#  56%|█████▌    | 14/25 [00:10<00:07,  1.38it/s, epoch=1/5, avg_epoch_loss=6.41]
# 100%|██████████| 25/25 [00:17<00:00,  1.41it/s, epoch=1/5, avg_epoch_loss=5.18]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:58<00:00,  2.35s/it, epoch=1/5, avg_epoch_loss=3.26]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.88it/s, epoch=3/5, avg_epoch_loss=1.9]
# 100%|██████████| 25/25 [00:53<00:00,  2.15s/it, epoch=1/5, avg_epoch_loss=3.4]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  40%|████      | 10/25 [00:10<00:15,  1.05s/it, epoch=5/5, avg_epoch_loss=1.52]
# 100%|██████████| 25/25 [00:16<00:00,  1.50it/s, epoch=1/5, avg_epoch_loss=5.37]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.84it/s, epoch=3/5, avg_epoch_loss=1.9]
# 100%|██████████| 25/25 [00:13<00:00,  1.91it/s, epoch=3/5, avg_epoch_loss=1.84]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  72%|███████▏  | 18/25 [00:20<00:07,  1.13s/it, epoch=5/5, avg_epoch_loss=1.4]
# 100%|██████████| 25/25 [00:08<00:00,  3.12it/s, epoch=2/5, avg_epoch_loss=2.41]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:14<00:00,  1.78it/s, epoch=3/5, avg_epoch_loss=1.89]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  40%|████      | 10/25 [00:11<00:17,  1.14s/it, epoch=2/5, avg_epoch_loss=2.81]
# 100%|██████████| 25/25 [00:08<00:00,  2.86it/s, epoch=2/5, avg_epoch_loss=3.84]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:18,  1.17s/it, epoch=2/5, avg_epoch_loss=2.6]
#  80%|████████  | 20/25 [00:22<00:05,  1.14s/it, epoch=5/5, avg_epoch_loss=1.44]
# 100%|██████████| 25/25 [00:27<00:00,  1.12s/it, epoch=5/5, avg_epoch_loss=1.34]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.83it/s, epoch=4/5, avg_epoch_loss=1.72]
# 100%|██████████| 25/25 [00:07<00:00,  3.14it/s, epoch=3/5, avg_epoch_loss=3.62]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.88it/s, epoch=4/5, avg_epoch_loss=1.89]
# 100%|██████████| 25/25 [00:13<00:00,  1.83it/s, epoch=4/5, avg_epoch_loss=1.78]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:27<00:00,  1.10s/it, epoch=5/5, avg_epoch_loss=1.44]
# 100%|██████████| 25/25 [00:13<00:00,  1.88it/s, epoch=4/5, avg_epoch_loss=1.77]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:09<00:00,  2.73it/s, epoch=3/5, avg_epoch_loss=4.41]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  80%|████████  | 20/25 [00:22<00:05,  1.10s/it, epoch=2/5, avg_epoch_loss=2.42]
#  72%|███████▏  | 18/25 [00:20<00:08,  1.17s/it, epoch=2/5, avg_epoch_loss=2.5]
# 100%|██████████| 25/25 [00:09<00:00,  2.76it/s, epoch=4/5, avg_epoch_loss=2.54]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:27<00:00,  1.12s/it, epoch=2/5, avg_epoch_loss=2.37]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:10<00:03,  1.84it/s, epoch=5/5, avg_epoch_loss=1.58]
# 100%|██████████| 25/25 [00:07<00:00,  3.16it/s, epoch=4/5, avg_epoch_loss=1.79]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:28<00:00,  1.13s/it, epoch=2/5, avg_epoch_loss=2.43]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:13<00:00,  1.87it/s, epoch=5/5, avg_epoch_loss=1.78]
#  72%|███████▏  | 18/25 [00:10<00:04,  1.70it/s, epoch=5/5, avg_epoch_loss=1.26]
# 100%|██████████| 25/25 [00:08<00:00,  2.99it/s, epoch=5/5, avg_epoch_loss=1.78]
# 100%|██████████| 25/25 [00:14<00:00,  1.71it/s, epoch=5/5, avg_epoch_loss=1.34]
# Running evaluation: 0it [00:00, ?it/s]m
#  36%|███▌      | 9/25 [00:10<00:17,  1.11s/it, epoch=3/5, avg_epoch_loss=1.46]
# 100%|██████████| 25/25 [00:09<00:00,  2.66it/s, epoch=5/5, avg_epoch_loss=2.02]
# Running evaluation: 41922it [00:01, 26590.58it/s]
#  32%|███▏      | 8/25 [00:10<00:22,  1.30s/it, epoch=3/5, avg_epoch_loss=1.52]
# Running evaluation: 0it [00:00, ?it/s]m
# Running evaluation: 41922it [00:02, 14610.16it/s]
#  36%|███▌      | 9/25 [00:25<00:17,  1.11s/it, epoch=3/5, avg_epoch_loss=1.54]
#  32%|███▏      | 8/25 [00:26<00:22,  1.30s/it, epoch=3/5, avg_epoch_loss=1.59]
#  56%|█████▌    | 14/25 [00:28<00:24,  2.22s/it, epoch=3/5, avg_epoch_loss=1.54]
#  48%|████▊     | 12/25 [00:26<00:32,  2.47s/it, epoch=3/5, avg_epoch_loss=1.58]
# (objectiveFNN pid=3099268) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099268)   return arr.astype(dtype, copy=True)
#   0%|          | 0/25 [00:00<?, ?it/s]m
# Running evaluation: 0it [00:00, ?it/s]m
#  68%|██████▊   | 17/25 [00:39<00:21,  2.65s/it, epoch=3/5, avg_epoch_loss=1.54]
# Running evaluation: 41922it [00:02, 15026.16it/s]
#  60%|██████    | 15/25 [00:39<00:30,  3.05s/it, epoch=3/5, avg_epoch_loss=1.68]
# (objectiveFNN pid=3099266) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099266)   return arr.astype(dtype, copy=True)
# Running evaluation: 0it [00:00, ?it/s]m
#   0%|          | 0/25 [00:00<?, ?it/s]m
# Running evaluation: 41922it [00:04, 9041.17it/s]
#  20%|██        | 5/25 [00:13<00:53,  2.65s/it, epoch=1/5, avg_epoch_loss=4.32]
#  88%|████████▊ | 22/25 [00:51<00:07,  2.52s/it, epoch=3/5, avg_epoch_loss=1.63]
# Running evaluation: 0it [00:00, ?it/s]m
#  80%|████████  | 20/25 [00:50<00:13,  2.70s/it, epoch=3/5, avg_epoch_loss=1.77]
# Running evaluation: 41922it [00:03, 10996.74it/s]
#   8%|▊         | 2/25 [00:10<01:58,  5.17s/it, epoch=1/5, avg_epoch_loss=1.81]
# 100%|██████████| 25/25 [01:03<00:00,  2.54s/it, epoch=3/5, avg_epoch_loss=1.65]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  20%|██        | 5/25 [00:31<00:53,  2.65s/it, epoch=1/5, avg_epoch_loss=3.89]
#  32%|███▏      | 8/25 [00:31<01:12,  4.24s/it, epoch=1/5, avg_epoch_loss=4.03]
#   8%|▊         | 2/25 [00:20<01:58,  5.17s/it, epoch=1/5, avg_epoch_loss=2.72]
#  16%|█▌        | 4/25 [00:20<01:48,  5.14s/it, epoch=1/5, avg_epoch_loss=3.96]
#  80%|████████  | 20/25 [01:06<00:13,  2.70s/it, epoch=3/5, avg_epoch_loss=1.74]
# (objectiveFNN pid=3099260) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099260)   return arr.astype(dtype, copy=True)
# Running evaluation: 0it [00:00, ?it/s]m
#  96%|█████████▌| 24/25 [01:10<00:03,  3.41s/it, epoch=3/5, avg_epoch_loss=1.75]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  12%|█▏        | 3/25 [00:14<01:44,  4.76s/it, epoch=4/5, avg_epoch_loss=1.75]
# Running evaluation: 41922it [00:08, 4759.85it/s]
#  32%|███▏      | 8/25 [00:41<01:12,  4.24s/it, epoch=1/5, avg_epoch_loss=4.87]
#  48%|████▊     | 12/25 [00:41<00:45,  3.46s/it, epoch=1/5, avg_epoch_loss=4.72]
# 100%|██████████| 25/25 [01:16<00:00,  3.07s/it, epoch=3/5, avg_epoch_loss=1.8]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  32%|███▏      | 8/25 [00:31<01:01,  3.62s/it, epoch=1/5, avg_epoch_loss=4.7]
# (objectiveFNN pid=3099270) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099270)   return arr.astype(dtype, copy=True)
#   8%|▊         | 2/25 [00:10<01:59,  5.19s/it, epoch=1/5, avg_epoch_loss=5.2]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  48%|████▊     | 12/25 [00:41<00:40,  3.11s/it, epoch=1/5, avg_epoch_loss=4.77]
#  76%|███████▌  | 19/25 [00:53<00:14,  2.49s/it, epoch=1/5, avg_epoch_loss=4.08]
#  28%|██▊       | 7/25 [00:26<01:06,  3.70s/it, epoch=4/5, avg_epoch_loss=1.79]
#  16%|█▌        | 4/25 [00:12<01:07,  3.20s/it, epoch=4/5, avg_epoch_loss=1.48]
#   8%|▊         | 2/25 [00:10<01:59,  5.19s/it, epoch=1/5, avg_epoch_loss=3.58]
# (objectiveFNN pid=3099262) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099262)   return arr.astype(dtype, copy=True)
#  20%|██        | 5/25 [00:24<01:35,  4.79s/it, epoch=1/5, avg_epoch_loss=4.63]
# 100%|██████████| 25/25 [01:01<00:00,  2.45s/it, epoch=1/5, avg_epoch_loss=3.77]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:52<00:13,  2.25s/it, epoch=1/5, avg_epoch_loss=4.26]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  16%|█▌        | 4/25 [00:20<01:47,  5.14s/it, epoch=1/5, avg_epoch_loss=3.61]
#  28%|██▊       | 7/25 [00:42<01:06,  3.70s/it, epoch=4/5, avg_epoch_loss=1.77]
# 100%|██████████| 25/25 [00:59<00:00,  2.37s/it, epoch=1/5, avg_epoch_loss=3.95]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  44%|████▍     | 11/25 [00:43<00:55,  3.97s/it, epoch=4/5, avg_epoch_loss=1.73]
#  20%|██        | 5/25 [00:34<01:35,  4.79s/it, epoch=1/5, avg_epoch_loss=4.98]
#  32%|███▏      | 8/25 [00:35<01:12,  4.26s/it, epoch=1/5, avg_epoch_loss=5.34]
#  16%|█▌        | 4/25 [00:29<01:07,  3.20s/it, epoch=4/5, avg_epoch_loss=1.67]
#  36%|███▌      | 9/25 [00:11<00:19,  1.22s/it, epoch=2/5, avg_epoch_loss=2.78]
#  32%|███▏      | 8/25 [00:30<01:06,  3.91s/it, epoch=4/5, avg_epoch_loss=1.6]
#  20%|██        | 5/25 [00:11<00:45,  2.26s/it, epoch=1/10, avg_epoch_loss=1.11]
# (objectiveFNN pid=3099264) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099264)   return arr.astype(dtype, copy=True)
#  28%|██▊       | 7/25 [00:31<01:17,  4.28s/it, epoch=1/5, avg_epoch_loss=4.01]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  40%|████      | 10/25 [00:10<00:16,  1.07s/it, epoch=2/5, avg_epoch_loss=2.71]
#  60%|██████    | 15/25 [00:54<00:34,  3.47s/it, epoch=4/5, avg_epoch_loss=1.67]
#  52%|█████▏    | 13/25 [00:46<00:37,  3.12s/it, epoch=1/5, avg_epoch_loss=4.71]
#  80%|████████  | 20/25 [00:21<00:05,  1.06s/it, epoch=2/5, avg_epoch_loss=2.6]
#  48%|████▊     | 12/25 [00:40<00:42,  3.29s/it, epoch=4/5, avg_epoch_loss=1.65]
#  56%|█████▌    | 14/25 [00:21<00:15,  1.45s/it, epoch=1/10, avg_epoch_loss=1.36]
# 100%|██████████| 25/25 [00:26<00:00,  1.05s/it, epoch=2/5, avg_epoch_loss=2.56]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  56%|█████▌    | 14/25 [00:43<00:28,  2.59s/it, epoch=1/5, avg_epoch_loss=3.99]
#  36%|███▌      | 9/25 [00:10<00:18,  1.18s/it, epoch=1/10, avg_epoch_loss=1.68]
#  84%|████████▍ | 21/25 [00:20<00:03,  1.02it/s, epoch=2/5, avg_epoch_loss=2.33]
#  84%|████████▍ | 21/25 [01:05<00:10,  2.71s/it, epoch=4/5, avg_epoch_loss=1.5]
#  76%|███████▌  | 19/25 [00:57<00:14,  2.50s/it, epoch=1/5, avg_epoch_loss=5.52]
# 100%|██████████| 25/25 [00:23<00:00,  1.05it/s, epoch=2/5, avg_epoch_loss=2.38]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  76%|███████▌  | 19/25 [00:52<00:14,  2.41s/it, epoch=4/5, avg_epoch_loss=1.64]
# 100%|██████████| 25/25 [00:31<00:00,  1.26s/it, epoch=1/10, avg_epoch_loss=1.22]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  44%|████▍     | 11/25 [00:10<00:13,  1.01it/s, epoch=3/5, avg_epoch_loss=2.45]
# 100%|██████████| 25/25 [01:13<00:00,  2.95s/it, epoch=4/5, avg_epoch_loss=1.49]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  56%|█████▌    | 14/25 [00:54<00:28,  2.59s/it, epoch=1/5, avg_epoch_loss=5.44]
#  84%|████████▍ | 21/25 [00:54<00:08,  2.12s/it, epoch=1/5, avg_epoch_loss=5.28]
#  80%|████████  | 20/25 [00:21<00:05,  1.05s/it, epoch=1/10, avg_epoch_loss=1.68]
# 100%|██████████| 25/25 [01:06<00:00,  2.67s/it, epoch=1/5, avg_epoch_loss=5.23]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [01:01<00:00,  2.48s/it, epoch=4/5, avg_epoch_loss=1.61]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:24<00:00,  1.04it/s, epoch=1/10, avg_epoch_loss=1.66]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  52%|█████▏    | 13/25 [00:10<00:09,  1.24it/s, epoch=3/5, avg_epoch_loss=2.65]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.85it/s, epoch=2/10, avg_epoch_loss=1.58]
#  92%|█████████▏| 23/25 [00:21<00:01,  1.09it/s, epoch=3/5, avg_epoch_loss=2.1]
# 100%|██████████| 25/25 [01:01<00:00,  2.46s/it, epoch=1/5, avg_epoch_loss=4.84]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:13<00:00,  1.81it/s, epoch=2/10, avg_epoch_loss=1.69]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:23<00:00,  1.08it/s, epoch=3/5, avg_epoch_loss=2.11]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  28%|██▊       | 7/25 [00:11<00:29,  1.63s/it, epoch=5/5, avg_epoch_loss=1.83]
#  28%|██▊       | 7/25 [00:11<00:29,  1.65s/it, epoch=2/5, avg_epoch_loss=2.73]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.86it/s, epoch=2/10, avg_epoch_loss=1.22]
#  28%|██▊       | 7/25 [00:10<00:27,  1.55s/it, epoch=5/5, avg_epoch_loss=1.69]
# 100%|██████████| 25/25 [00:21<00:00,  1.15it/s, epoch=3/5, avg_epoch_loss=2.18]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:12<00:00,  1.95it/s, epoch=2/10, avg_epoch_loss=1.26]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  28%|██▊       | 7/25 [00:11<00:29,  1.61s/it, epoch=2/5, avg_epoch_loss=3.17]
#  80%|████████  | 20/25 [00:10<00:02,  1.95it/s, epoch=3/10, avg_epoch_loss=1.29]
#  48%|████▊     | 12/25 [00:10<00:11,  1.17it/s, epoch=4/5, avg_epoch_loss=2.46]
#  56%|█████▌    | 14/25 [00:22<00:17,  1.61s/it, epoch=5/5, avg_epoch_loss=1.78]
# 100%|██████████| 25/25 [00:13<00:00,  1.91it/s, epoch=3/10, avg_epoch_loss=1.26]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  56%|█████▌    | 14/25 [00:22<00:17,  1.63s/it, epoch=2/5, avg_epoch_loss=3.25]
#  56%|█████▌    | 14/25 [00:21<00:17,  1.57s/it, epoch=5/5, avg_epoch_loss=1.63]
#  48%|████▊     | 12/25 [00:10<00:11,  1.13it/s, epoch=4/5, avg_epoch_loss=1.63]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.89it/s, epoch=3/10, avg_epoch_loss=1.23]
# 100%|██████████| 25/25 [00:13<00:00,  1.87it/s, epoch=3/10, avg_epoch_loss=1.36]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  48%|████▊     | 12/25 [00:21<00:11,  1.17it/s, epoch=4/5, avg_epoch_loss=2.04]
# 100%|██████████| 25/25 [00:21<00:00,  1.18it/s, epoch=4/5, avg_epoch_loss=1.99]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  28%|██▊       | 7/25 [00:22<00:29,  1.61s/it, epoch=2/5, avg_epoch_loss=3.04]
#  56%|█████▌    | 14/25 [00:23<00:18,  1.66s/it, epoch=2/5, avg_epoch_loss=2.92]
#  72%|███████▏  | 18/25 [00:10<00:03,  1.79it/s, epoch=4/10, avg_epoch_loss=1.43]
#  84%|████████▍ | 21/25 [00:35<00:06,  1.71s/it, epoch=5/5, avg_epoch_loss=1.65]
# 100%|██████████| 25/25 [00:21<00:00,  1.19it/s, epoch=4/5, avg_epoch_loss=1.47]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:14<00:00,  1.74it/s, epoch=4/10, avg_epoch_loss=1.44]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  84%|████████▍ | 21/25 [00:35<00:06,  1.73s/it, epoch=2/5, avg_epoch_loss=3.12]
#  84%|████████▍ | 21/25 [00:35<00:06,  1.71s/it, epoch=5/5, avg_epoch_loss=1.55]
#  72%|███████▏  | 18/25 [00:10<00:03,  1.76it/s, epoch=4/10, avg_epoch_loss=1.91]
#  48%|████▊     | 12/25 [00:10<00:11,  1.18it/s, epoch=5/5, avg_epoch_loss=3.57]
#  80%|████████  | 20/25 [00:33<00:08,  1.69s/it, epoch=2/5, avg_epoch_loss=2.56]
# 100%|██████████| 25/25 [00:42<00:00,  1.71s/it, epoch=5/5, avg_epoch_loss=1.59]
# 100%|██████████| 25/25 [00:13<00:00,  1.79it/s, epoch=4/10, avg_epoch_loss=1.79]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:43<00:00,  1.74s/it, epoch=2/5, avg_epoch_loss=3.11]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:42<00:00,  1.70s/it, epoch=5/5, avg_epoch_loss=1.51]
#  44%|████▍     | 11/25 [00:10<00:13,  1.06it/s, epoch=5/5, avg_epoch_loss=1.6]
#  80%|████████  | 20/25 [00:10<00:02,  1.98it/s, epoch=5/10, avg_epoch_loss=1.58]
# 100%|██████████| 25/25 [00:41<00:00,  1.67s/it, epoch=2/5, avg_epoch_loss=2.46]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:12<00:00,  1.95it/s, epoch=5/10, avg_epoch_loss=1.47]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:21<00:00,  1.19it/s, epoch=5/5, avg_epoch_loss=2.41]
#  72%|███████▏  | 18/25 [00:10<00:03,  1.76it/s, epoch=5/10, avg_epoch_loss=1.11]
#  28%|██▊       | 7/25 [00:10<00:27,  1.55s/it, epoch=3/5, avg_epoch_loss=2.02]
#  92%|█████████▏| 23/25 [00:21<00:01,  1.09it/s, epoch=5/5, avg_epoch_loss=1.78]
# 100%|██████████| 25/25 [00:14<00:00,  1.78it/s, epoch=5/10, avg_epoch_loss=1.19]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# 100%|██████████| 25/25 [00:23<00:00,  1.09it/s, epoch=5/5, avg_epoch_loss=1.81]
#  84%|████████▍ | 21/25 [00:10<00:01,  2.05it/s, epoch=6/10, avg_epoch_loss=1.33]
#  24%|██▍       | 6/25 [00:10<00:34,  1.81s/it, epoch=3/5, avg_epoch_loss=1.58]
# 100%|██████████| 25/25 [00:12<00:00,  1.98it/s, epoch=6/10, avg_epoch_loss=1.32]
#   0%|          | 0/25 [00:00<?, ?it/s]m
# Running evaluation: 0it [00:00, ?it/s]m
# Running evaluation: 41922it [00:02, 15964.28it/s]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.67it/s, epoch=6/10, avg_epoch_loss=1.05]
# Running evaluation: 0it [00:00, ?it/s]m
#  56%|█████▌    | 14/25 [00:23<00:18,  1.70s/it, epoch=3/5, avg_epoch_loss=1.85]
#  24%|██▍       | 6/25 [00:21<00:34,  1.81s/it, epoch=3/5, avg_epoch_loss=2.09]
#  48%|████▊     | 12/25 [00:21<00:23,  1.78s/it, epoch=3/5, avg_epoch_loss=2.11]
#  52%|█████▏    | 13/25 [00:10<00:09,  1.24it/s, epoch=7/10, avg_epoch_loss=1.25]
# Running evaluation: 41922it [00:07, 5459.83it/s]
# Running evaluation: 0it [00:00, ?it/s]m
#  56%|█████▌    | 14/25 [00:34<00:18,  1.70s/it, epoch=3/5, avg_epoch_loss=2.01]
# Running evaluation: 41922it [00:02, 14076.99it/s]
#  80%|████████  | 20/25 [00:35<00:09,  1.81s/it, epoch=3/5, avg_epoch_loss=2]
#  68%|██████▊   | 17/25 [00:24<00:04,  1.67it/s, epoch=6/10, avg_epoch_loss=1.1]
#  92%|█████████▏| 23/25 [00:24<00:02,  1.20s/it, epoch=6/10, avg_epoch_loss=1.1]
#  72%|███████▏  | 18/25 [00:33<00:13,  1.88s/it, epoch=3/5, avg_epoch_loss=2.05]
# Running evaluation: 0it [00:00, ?it/s]m
# 100%|██████████| 25/25 [00:32<00:00,  1.29s/it, epoch=6/10, avg_epoch_loss=1.09]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  52%|█████▏    | 13/25 [00:28<00:09,  1.24it/s, epoch=7/10, avg_epoch_loss=1.21]
# 100%|██████████| 25/25 [00:49<00:00,  1.98s/it, epoch=3/5, avg_epoch_loss=2.05]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  80%|████████  | 20/25 [00:32<00:09,  1.83s/it, epoch=7/10, avg_epoch_loss=1.23]
# Running evaluation: 1it [00:10, 10.38s/it]
# Running evaluation: 41922it [00:10, 3960.22it/s]
#  72%|███████▏  | 18/25 [00:51<00:13,  1.88s/it, epoch=3/5, avg_epoch_loss=2.26]
#  12%|█▏        | 3/25 [00:12<01:29,  4.08s/it, epoch=7/10, avg_epoch_loss=1.25]
#  92%|█████████▏| 23/25 [00:58<00:05,  2.96s/it, epoch=3/5, avg_epoch_loss=2.23]
#  80%|████████  | 20/25 [00:48<00:09,  1.83s/it, epoch=7/10, avg_epoch_loss=1.27]
#   8%|▊         | 2/25 [00:16<03:12,  8.35s/it, epoch=4/5, avg_epoch_loss=2.03]
#  96%|█████████▌| 24/25 [00:53<00:02,  2.70s/it, epoch=7/10, avg_epoch_loss=1.33]
# 100%|██████████| 25/25 [00:57<00:00,  2.29s/it, epoch=7/10, avg_epoch_loss=1.37]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  92%|█████████▏| 23/25 [01:11<00:05,  2.96s/it, epoch=3/5, avg_epoch_loss=2.23]
#  24%|██▍       | 6/25 [00:31<01:42,  5.40s/it, epoch=7/10, avg_epoch_loss=1.19]
#  16%|█▌        | 4/25 [00:30<02:36,  7.45s/it, epoch=4/5, avg_epoch_loss=1.74]
# 100%|██████████| 25/25 [01:16<00:00,  3.05s/it, epoch=3/5, avg_epoch_loss=2.19]
#   0%|          | 0/25 [00:00<?, ?it/s]m
#  12%|█▏        | 3/25 [00:11<01:24,  3.85s/it, epoch=8/10, avg_epoch_loss=1.26]
#  24%|██▍       | 6/25 [00:42<01:42,  5.40s/it, epoch=7/10, avg_epoch_loss=1.24]
#  36%|███▌      | 9/25 [00:44<01:18,  4.90s/it, epoch=7/10, avg_epoch_loss=1.3]
#   4%|▍         | 1/25 [00:12<04:49, 12.06s/it, epoch=4/5, avg_epoch_loss=1.23]
#  16%|█▌        | 4/25 [00:45<02:36,  7.45s/it, epoch=4/5, avg_epoch_loss=1.78]
# ...
#  38%|███▊      | 19/50 [00:21<00:34,  1.11s/it, epoch=18/20, avg_epoch_loss=0.935]
#  64%|██████▍   | 32/50 [00:42<00:21,  1.21s/it, epoch=1/20, avg_epoch_loss=4.39]
# Running evaluation: 0it [00:00, ?it/s]m
# Running evaluation: 41922it [00:02, 18994.89it/s]
#  78%|███████▊  | 39/50 [00:41<00:11,  1.07s/it, epoch=9/20, avg_epoch_loss=1.05]
#  34%|███▍      | 17/50 [00:10<00:19,  1.67it/s, epoch=3/20, avg_epoch_loss=1.86]
#  76%|███████▌  | 38/50 [00:53<00:13,  1.10s/it, epoch=9/20, avg_epoch_loss=1]
#  96%|█████████▌| 48/50 [00:54<00:02,  1.15s/it, epoch=9/20, avg_epoch_loss=1]
#  38%|███▊      | 19/50 [00:23<00:16,  1.84it/s, epoch=4/20, avg_epoch_loss=1.3]
#  76%|███████▌  | 38/50 [00:23<00:07,  1.59it/s, epoch=4/20, avg_epoch_loss=1.3]
#  80%|████████  | 40/50 [00:46<00:12,  1.20s/it, epoch=18/20, avg_epoch_loss=0.899]
# 100%|██████████| 50/50 [00:59<00:00,  1.18s/it, epoch=9/20, avg_epoch_loss=1.01]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  58%|█████▊    | 29/50 [00:36<00:27,  1.30s/it, epoch=18/20, avg_epoch_loss=0.977]
#  84%|████████▍ | 42/50 [01:00<00:11,  1.42s/it, epoch=1/20, avg_epoch_loss=3.89]
#  78%|███████▊  | 39/50 [00:54<00:11,  1.07s/it, epoch=9/20, avg_epoch_loss=1.04]
#  90%|█████████ | 45/50 [00:55<00:06,  1.38s/it, epoch=9/20, avg_epoch_loss=1.05]
#  34%|███▍      | 17/50 [00:25<00:19,  1.67it/s, epoch=3/20, avg_epoch_loss=1.78]
#  62%|██████▏   | 31/50 [00:25<00:16,  1.16it/s, epoch=3/20, avg_epoch_loss=1.76]
# (objectiveFNN pid=3099266) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099266)   return arr.astype(dtype, copy=True)
# 100%|██████████| 50/50 [00:37<00:00,  1.33it/s, epoch=4/20, avg_epoch_loss=1.24]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  12%|█▏        | 6/50 [00:10<01:19,  1.81s/it, epoch=10/20, avg_epoch_loss=1.1]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  72%|███████▏  | 36/50 [00:47<00:19,  1.39s/it, epoch=18/20, avg_epoch_loss=0.95]
# 100%|██████████| 50/50 [01:02<00:00,  1.24s/it, epoch=9/20, avg_epoch_loss=1.07]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  96%|█████████▌| 48/50 [01:01<00:02,  1.40s/it, epoch=18/20, avg_epoch_loss=0.898]
# 100%|██████████| 50/50 [01:09<00:00,  1.40s/it, epoch=1/20, avg_epoch_loss=3.55]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [01:03<00:00,  1.27s/it, epoch=18/20, avg_epoch_loss=0.904]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [00:35<00:00,  1.43it/s, epoch=3/20, avg_epoch_loss=1.6]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  38%|███▊      | 19/50 [00:10<00:16,  1.83it/s, epoch=5/20, avg_epoch_loss=1.41]
#  30%|███       | 15/50 [00:21<00:47,  1.35s/it, epoch=10/20, avg_epoch_loss=1.15]
#   8%|▊         | 4/50 [00:10<01:56,  2.53s/it, epoch=1/20, avg_epoch_loss=3.08]
#  18%|█▊        | 9/50 [00:10<00:46,  1.13s/it, epoch=10/20, avg_epoch_loss=0.927]
#  90%|█████████ | 45/50 [00:58<00:06,  1.32s/it, epoch=18/20, avg_epoch_loss=0.951]
#  18%|█▊        | 9/50 [00:10<00:47,  1.15s/it, epoch=19/20, avg_epoch_loss=0.757]
#  20%|██        | 10/50 [00:10<00:43,  1.09s/it, epoch=2/20, avg_epoch_loss=2.82]
#  36%|███▌      | 18/50 [00:10<00:18,  1.77it/s, epoch=4/20, avg_epoch_loss=1.28]
# 100%|██████████| 50/50 [01:04<00:00,  1.29s/it, epoch=18/20, avg_epoch_loss=0.944]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  20%|██        | 10/50 [00:20<01:18,  1.95s/it, epoch=1/20, avg_epoch_loss=4.7]
#  48%|████▊     | 24/50 [00:31<00:32,  1.24s/it, epoch=10/20, avg_epoch_loss=1.11]
#  78%|███████▊  | 39/50 [00:20<00:05,  1.88it/s, epoch=5/20, avg_epoch_loss=1.29]
#  38%|███▊      | 19/50 [00:20<00:33,  1.10s/it, epoch=10/20, avg_epoch_loss=1]
# 100%|██████████| 50/50 [00:26<00:00,  1.89it/s, epoch=5/20, avg_epoch_loss=1.35]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  38%|███▊      | 19/50 [00:21<00:34,  1.10s/it, epoch=19/20, avg_epoch_loss=0.82]
#  40%|████      | 20/50 [00:22<00:33,  1.12s/it, epoch=2/20, avg_epoch_loss=2.91]
#  74%|███████▍  | 37/50 [00:20<00:07,  1.85it/s, epoch=4/20, avg_epoch_loss=1.35]
#  20%|██        | 10/50 [00:10<00:43,  1.08s/it, epoch=19/20, avg_epoch_loss=0.735]
#  68%|██████▊   | 34/50 [00:42<00:18,  1.17s/it, epoch=10/20, avg_epoch_loss=1.08]
#  40%|████      | 20/50 [00:31<00:42,  1.42s/it, epoch=1/20, avg_epoch_loss=4.45]
#  58%|█████▊    | 29/50 [00:32<00:23,  1.13s/it, epoch=10/20, avg_epoch_loss=1.01]
# 100%|██████████| 50/50 [00:27<00:00,  1.81it/s, epoch=4/20, avg_epoch_loss=1.4]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  36%|███▌      | 18/50 [00:10<00:18,  1.77it/s, epoch=6/20, avg_epoch_loss=1.36]
#  60%|██████    | 30/50 [00:32<00:21,  1.07s/it, epoch=2/20, avg_epoch_loss=2.57]
#  60%|██████    | 30/50 [00:32<00:21,  1.05s/it, epoch=19/20, avg_epoch_loss=0.857]
#  40%|████      | 20/50 [00:22<00:34,  1.15s/it, epoch=19/20, avg_epoch_loss=0.779]
#  60%|██████    | 30/50 [00:42<00:25,  1.27s/it, epoch=1/20, avg_epoch_loss=3.68]
#  88%|████████▊ | 44/50 [00:53<00:06,  1.15s/it, epoch=10/20, avg_epoch_loss=1.09]
#  78%|███████▊  | 39/50 [00:42<00:11,  1.08s/it, epoch=10/20, avg_epoch_loss=1]
#  38%|███▊      | 19/50 [00:10<00:16,  1.87it/s, epoch=5/20, avg_epoch_loss=1.49]
#  74%|███████▍  | 37/50 [00:20<00:07,  1.83it/s, epoch=6/20, avg_epoch_loss=1.23]
#  80%|████████  | 40/50 [00:42<00:10,  1.05s/it, epoch=19/20, avg_epoch_loss=0.844]
#  80%|████████  | 40/50 [00:43<00:10,  1.07s/it, epoch=2/20, avg_epoch_loss=2.78]
# 100%|██████████| 50/50 [00:59<00:00,  1.19s/it, epoch=10/20, avg_epoch_loss=1.08]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  58%|█████▊    | 29/50 [00:33<00:23,  1.14s/it, epoch=19/20, avg_epoch_loss=0.813]
#  80%|████████  | 40/50 [00:52<00:11,  1.18s/it, epoch=1/20, avg_epoch_loss=3.36]
# 100%|██████████| 50/50 [00:28<00:00,  1.78it/s, epoch=6/20, avg_epoch_loss=1.4]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  78%|███████▊  | 39/50 [00:52<00:11,  1.08s/it, epoch=10/20, avg_epoch_loss=0.994]
#  96%|█████████▌| 48/50 [00:54<00:02,  1.15s/it, epoch=10/20, avg_epoch_loss=0.992]
#  38%|███▊      | 19/50 [00:22<00:16,  1.87it/s, epoch=5/20, avg_epoch_loss=1.27]
#  76%|███████▌  | 38/50 [00:23<00:07,  1.58it/s, epoch=5/20, avg_epoch_loss=1.27]
#  12%|█▏        | 6/50 [00:10<01:16,  1.75s/it, epoch=11/20, avg_epoch_loss=1.01]
# 100%|██████████| 50/50 [00:59<00:00,  1.19s/it, epoch=10/20, avg_epoch_loss=0.989]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  80%|████████  | 40/50 [00:58<00:10,  1.05s/it, epoch=19/20, avg_epoch_loss=0.851]
#  14%|█▍        | 7/50 [00:10<01:03,  1.48s/it, epoch=7/20, avg_epoch_loss=1.13]
#  58%|█████▊    | 29/50 [00:45<00:23,  1.14s/it, epoch=19/20, avg_epoch_loss=0.84]
#  96%|█████████▌| 48/50 [00:59<00:02,  1.38s/it, epoch=19/20, avg_epoch_loss=0.852]
#  80%|████████  | 40/50 [01:00<00:10,  1.07s/it, epoch=2/20, avg_epoch_loss=2.55]
#  80%|████████  | 40/50 [01:05<00:11,  1.18s/it, epoch=1/20, avg_epoch_loss=3.31]
#  70%|███████   | 35/50 [00:47<00:22,  1.49s/it, epoch=19/20, avg_epoch_loss=0.844]
# 100%|██████████| 50/50 [01:01<00:00,  1.24s/it, epoch=2/20, avg_epoch_loss=2.52]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  90%|█████████ | 45/50 [01:07<00:07,  1.57s/it, epoch=1/20, avg_epoch_loss=3.35]
# 100%|██████████| 50/50 [01:03<00:00,  1.26s/it, epoch=19/20, avg_epoch_loss=0.85]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [00:35<00:00,  1.43it/s, epoch=5/20, avg_epoch_loss=1.25]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  24%|██▍       | 12/50 [00:22<01:11,  1.89s/it, epoch=11/20, avg_epoch_loss=0.972]
#  14%|█▍        | 7/50 [00:10<01:04,  1.50s/it, epoch=11/20, avg_epoch_loss=0.946]
# 100%|██████████| 50/50 [01:12<00:00,  1.45s/it, epoch=1/20, avg_epoch_loss=3.2]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  44%|████▍     | 22/50 [00:20<00:24,  1.14it/s, epoch=7/20, avg_epoch_loss=1.19]
#  90%|█████████ | 45/50 [00:57<00:06,  1.33s/it, epoch=19/20, avg_epoch_loss=0.858]
#  20%|██        | 10/50 [00:10<00:43,  1.08s/it, epoch=3/20, avg_epoch_loss=1.71]
#  22%|██▏       | 11/50 [00:10<00:37,  1.03it/s, epoch=20/20, avg_epoch_loss=0.982]
#  38%|███▊      | 19/50 [00:10<00:16,  1.85it/s, epoch=6/20, avg_epoch_loss=1.07]
#  44%|████▍     | 22/50 [00:33<00:40,  1.43s/it, epoch=11/20, avg_epoch_loss=0.961]
# 100%|██████████| 50/50 [01:03<00:00,  1.27s/it, epoch=19/20, avg_epoch_loss=0.859]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  34%|███▍      | 17/50 [00:21<00:39,  1.21s/it, epoch=11/20, avg_epoch_loss=0.96]
#  20%|██        | 10/50 [00:10<00:42,  1.06s/it, epoch=2/20, avg_epoch_loss=3.07]
#  86%|████████▌ | 43/50 [00:30<00:04,  1.54it/s, epoch=7/20, avg_epoch_loss=1.18]
#  40%|████      | 20/50 [00:21<00:31,  1.06s/it, epoch=3/20, avg_epoch_loss=1.67]
# 100%|██████████| 50/50 [00:34<00:00,  1.45it/s, epoch=7/20, avg_epoch_loss=1.22]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  44%|████▍     | 22/50 [00:22<00:28,  1.02s/it, epoch=20/20, avg_epoch_loss=0.948]
#  76%|███████▌  | 38/50 [00:20<00:06,  1.84it/s, epoch=6/20, avg_epoch_loss=1.28]
#  20%|██        | 10/50 [00:10<00:40,  1.00s/it, epoch=20/20, avg_epoch_loss=0.993]
#  64%|██████▍   | 32/50 [00:44<00:22,  1.28s/it, epoch=11/20, avg_epoch_loss=0.977]
#  54%|█████▍    | 27/50 [00:31<00:25,  1.12s/it, epoch=11/20, avg_epoch_loss=0.926]
#  40%|████      | 20/50 [00:21<00:32,  1.10s/it, epoch=2/20, avg_epoch_loss=2.87]
# 100%|██████████| 50/50 [00:27<00:00,  1.83it/s, epoch=6/20, avg_epoch_loss=1.25]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  38%|███▊      | 19/50 [00:10<00:16,  1.82it/s, epoch=8/20, avg_epoch_loss=1.15]
#  60%|██████    | 30/50 [00:32<00:21,  1.08s/it, epoch=3/20, avg_epoch_loss=1.55]
#  64%|██████▍   | 32/50 [00:33<00:18,  1.04s/it, epoch=20/20, avg_epoch_loss=0.957]
#  40%|████      | 20/50 [00:20<00:30,  1.03s/it, epoch=20/20, avg_epoch_loss=0.954]
#  64%|██████▍   | 32/50 [00:54<00:22,  1.28s/it, epoch=11/20, avg_epoch_loss=0.997]
#  74%|███████▍  | 37/50 [00:41<00:14,  1.09s/it, epoch=11/20, avg_epoch_loss=0.951]
#  84%|████████▍ | 42/50 [00:55<00:09,  1.21s/it, epoch=11/20, avg_epoch_loss=1]
#  58%|█████▊    | 29/50 [00:32<00:23,  1.12s/it, epoch=2/20, avg_epoch_loss=2.53]
#  40%|████      | 20/50 [00:10<00:15,  1.93it/s, epoch=7/20, avg_epoch_loss=1.14]
#  76%|███████▌  | 38/50 [00:20<00:06,  1.85it/s, epoch=8/20, avg_epoch_loss=1.16]
#  80%|████████  | 40/50 [00:42<00:10,  1.05s/it, epoch=3/20, avg_epoch_loss=1.58]
#  84%|████████▍ | 42/50 [00:43<00:08,  1.04s/it, epoch=20/20, avg_epoch_loss=0.934]
# 100%|██████████| 50/50 [01:04<00:00,  1.29s/it, epoch=11/20, avg_epoch_loss=0.986]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  94%|█████████▍| 47/50 [00:52<00:03,  1.06s/it, epoch=11/20, avg_epoch_loss=0.941]
#  40%|████      | 20/50 [00:32<00:30,  1.03s/it, epoch=20/20, avg_epoch_loss=0.928]
#  76%|███████▌  | 38/50 [00:42<00:13,  1.12s/it, epoch=2/20, avg_epoch_loss=2.27]
#  60%|██████    | 30/50 [00:32<00:22,  1.12s/it, epoch=20/20, avg_epoch_loss=0.939]
# 100%|██████████| 50/50 [00:27<00:00,  1.85it/s, epoch=8/20, avg_epoch_loss=1.11]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [00:54<00:00,  1.10s/it, epoch=11/20, avg_epoch_loss=0.938]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  80%|████████  | 40/50 [00:20<00:05,  1.90it/s, epoch=7/20, avg_epoch_loss=1.09]
# 100%|██████████| 50/50 [00:52<00:00,  1.06s/it, epoch=3/20, avg_epoch_loss=1.54]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [00:51<00:00,  1.03s/it, epoch=20/20, avg_epoch_loss=0.912]
#  20%|██        | 10/50 [00:11<00:44,  1.10s/it, epoch=12/20, avg_epoch_loss=0.956]
# 100%|██████████| 50/50 [00:26<00:00,  1.89it/s, epoch=7/20, avg_epoch_loss=1.13]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  38%|███▊      | 19/50 [00:10<00:16,  1.89it/s, epoch=9/20, avg_epoch_loss=1.01]
#  94%|█████████▍| 47/50 [00:53<00:03,  1.15s/it, epoch=2/20, avg_epoch_loss=2.15]
#  80%|████████  | 40/50 [00:43<00:11,  1.12s/it, epoch=20/20, avg_epoch_loss=0.937]
#  20%|██        | 10/50 [00:10<00:42,  1.06s/it, epoch=12/20, avg_epoch_loss=1.18]
# 100%|██████████| 50/50 [00:56<00:00,  1.13s/it, epoch=2/20, avg_epoch_loss=2.1]
#   0%|          | 0/50 [00:00<?, ?it/s]m
#  22%|██▏       | 11/50 [00:10<00:38,  1.00it/s, epoch=4/20, avg_epoch_loss=1.24]
#  38%|███▊      | 19/50 [00:10<00:17,  1.80it/s, epoch=8/20, avg_epoch_loss=1.56]
#  40%|████      | 20/50 [00:22<00:33,  1.10s/it, epoch=12/20, avg_epoch_loss=0.989]
#  78%|███████▊  | 39/50 [00:20<00:05,  1.89it/s, epoch=9/20, avg_epoch_loss=1.01]
# 100%|██████████| 50/50 [00:54<00:00,  1.10s/it, epoch=20/20, avg_epoch_loss=0.939]
#  40%|████      | 20/50 [00:21<00:32,  1.07s/it, epoch=12/20, avg_epoch_loss=1.08]
#  18%|█▊        | 9/50 [00:10<00:47,  1.16s/it, epoch=3/20, avg_epoch_loss=1.22]
# 100%|██████████| 50/50 [00:26<00:00,  1.87it/s, epoch=9/20, avg_epoch_loss=1.05]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# Running evaluation: 0it [00:00, ?it/s]m
#  44%|████▍     | 22/50 [00:23<00:30,  1.09s/it, epoch=4/20, avg_epoch_loss=1.37]
# Running evaluation: 41922it [00:02, 20953.06it/s]
#  76%|███████▌  | 38/50 [00:21<00:06,  1.81it/s, epoch=8/20, avg_epoch_loss=1.32]
#  60%|██████    | 30/50 [00:35<00:23,  1.20s/it, epoch=12/20, avg_epoch_loss=1.01]
#  18%|█▊        | 9/50 [00:11<00:52,  1.29s/it, epoch=10/20, avg_epoch_loss=1.24]
#  60%|██████    | 30/50 [00:37<00:26,  1.32s/it, epoch=12/20, avg_epoch_loss=1.06]
#  44%|████▍     | 22/50 [00:35<00:30,  1.09s/it, epoch=4/20, avg_epoch_loss=1.36]
#  18%|█▊        | 9/50 [00:26<00:47,  1.16s/it, epoch=3/20, avg_epoch_loss=1.27]
#  58%|█████▊    | 29/50 [00:37<00:29,  1.40s/it, epoch=4/20, avg_epoch_loss=1.34]
#  34%|███▍      | 17/50 [00:28<00:58,  1.76s/it, epoch=3/20, avg_epoch_loss=1.27]
#  76%|███████▌  | 38/50 [00:33<00:06,  1.81it/s, epoch=8/20, avg_epoch_loss=1.3]
# 100%|██████████| 50/50 [00:34<00:00,  1.45it/s, epoch=8/20, avg_epoch_loss=1.31]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# (objectiveFNN pid=3099260) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099260)   return arr.astype(dtype, copy=True)
#  60%|██████    | 30/50 [00:50<00:23,  1.20s/it, epoch=12/20, avg_epoch_loss=0.997]
# Running evaluation: 0it [00:00, ?it/s]m
#   0%|          | 0/100 [00:00<?, ?it/s]
#  76%|███████▌  | 38/50 [00:50<00:17,  1.45s/it, epoch=12/20, avg_epoch_loss=0.992]
#  38%|███▊      | 19/50 [00:21<00:34,  1.12s/it, epoch=10/20, avg_epoch_loss=1.08]
#  74%|███████▍  | 37/50 [00:48<00:18,  1.39s/it, epoch=12/20, avg_epoch_loss=1.04]
# Running evaluation: 41922it [00:02, 17101.21it/s]
#  72%|███████▏  | 36/50 [00:47<00:19,  1.42s/it, epoch=4/20, avg_epoch_loss=1.36]
#  48%|████▊     | 24/50 [00:39<00:43,  1.68s/it, epoch=3/20, avg_epoch_loss=1.29]
#  26%|██▌       | 13/50 [00:11<00:32,  1.13it/s, epoch=9/20, avg_epoch_loss=1.21]
#   8%|▊         | 8/100 [00:10<01:56,  1.27s/it, epoch=1/5, avg_epoch_loss=1.49]
#  58%|█████▊    | 29/50 [00:32<00:23,  1.10s/it, epoch=10/20, avg_epoch_loss=1.07]
#  88%|████████▊ | 44/50 [01:05<00:10,  1.74s/it, epoch=12/20, avg_epoch_loss=0.963]
# (objectiveFNN pid=3099270) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=3099270)   return arr.astype(dtype, copy=True)
#  88%|████████▊ | 44/50 [01:05<00:10,  1.72s/it, epoch=12/20, avg_epoch_loss=1.06]
#  62%|██████▏   | 31/50 [00:53<00:34,  1.81s/it, epoch=3/20, avg_epoch_loss=1.33]
#   8%|▊         | 8/100 [00:20<01:56,  1.27s/it, epoch=1/5, avg_epoch_loss=1.45]
#   0%|          | 0/100 [00:00<?, ?it/s]
#  17%|█▋        | 17/100 [00:20<01:39,  1.19s/it, epoch=1/5, avg_epoch_loss=1.38]
#  50%|█████     | 25/50 [00:25<00:26,  1.06s/it, epoch=9/20, avg_epoch_loss=1.1]
#  86%|████████▌ | 43/50 [01:04<00:12,  1.75s/it, epoch=4/20, avg_epoch_loss=1.3]
#  84%|████████▍ | 42/50 [00:43<00:07,  1.04it/s, epoch=10/20, avg_epoch_loss=1.01]
# 100%|██████████| 50/50 [01:14<00:00,  1.48s/it, epoch=12/20, avg_epoch_loss=0.971]
#   0%|          | 0/50 [00:00<?, ?it/s]m
# 100%|██████████| 50/50 [01:12<00:00,  1.44s/it, epoch=12/20, avg_epoch_loss=1.02]
#   0%|          | 0/50 [00:00<?, ?it/s]m
