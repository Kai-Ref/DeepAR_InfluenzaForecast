# %%
import os
os.chdir('/home/reffert/DeepAR_InfluenzaForecast')
from PythonFiles.model import model, preprocessing, split_forecasts_by_week, plot_coverage, print_forecasts_by_week, forecast_by_week, train_test_split, update_deepAR_parameters
from PythonFiles.Configuration import Configuration
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from gluonts.model.simple_feedforward import SimpleFeedForwardEstimator
from gluonts.mx import Trainer
from gluonts.evaluation import make_evaluation_predictions
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.rolling_dataset import generate_rolling_dataset,StepStrategy
from gluonts.evaluation import make_evaluation_predictions, Evaluator
import ray
from ray.air import session
from ray import tune
from gluonts.mx.distribution import NegativeBinomialOutput
config = Configuration()
influenza_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/influenza.csv", sep=',')
population_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/PopulationVector.csv", sep=',')
neighbourhood_df = pd.read_csv("/home/reffert/DeepAR_InfluenzaForecast/Notebooks/DataProcessing/AdjacentMatrix.csv", sep=',', index_col=0)

config.train_start_time = datetime(1999,1,1,0,0,0)#datetime(2010,1,1,0,0,0)
config.train_end_time = datetime(2016,9,30,23,0,0)
config.test_end_time = datetime(2018,9,30,23,0,0)
overall_evaluation_df = pd.DataFrame()

data_splits_dict = {}
output_dict = {}

locations = list(influenza_df.location.unique())
#Process the df into a uniformly spaced df
df = influenza_df.loc[influenza_df.location.isin(locations), ['value', 'location', 'date','week']]
df = preprocessing(config, df, check_count=False, output_type="corrected_df")
for location in locations:
    df.loc[df.location == location, "population"] = int(population_df.loc[population_df.Location == location, "2011"].values[0])
    df.loc[df.location == location, locations] = neighbourhood_df.loc[neighbourhood_df.index==location,locations].values[0].astype(int)
    
# Data split with no additional features and training start in 2010
#data_splits_dict["without_features_2001"] = list(train_test_split(config, df, False))
data_splits_dict["with_features_2001"] = list(train_test_split(config, df, True))

# Change the beginning of the training period
#config.train_start_time = datetime(2010,1,1,0,0,0)
#data_splits_dict["without_features_2010"] = list(train_test_split(config, df, False))
#data_splits_dict["with_features_2010"] = list(train_test_split(config, df, True))
# Out:
# /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/gluonts/model/simple_feedforward/__init__.py:18: FutureWarning: The module gluonts.model.simple_feedforward has been moved to gluonts.mx.model.simple_feedforward. In GluonTS v0.12 it will be no longer possible to use the old path. Try to use 'from gluonts.mx import SimpleFeedForwardEstimator'.
#   warnings.warn(

# %%
def update_FNN_parameters(config, new_parameters):
    ''' 
    This function updates the DeepAR-configuration in the Configuration.py file. 
    Note that new_parameters must be a dict containing the exact keys used in config.parameters.
    '''
    parameters = config.fnnparameters.copy()
    for key in new_parameters.keys():
        if key in parameters.keys():
            parameters[key] = new_parameters[key]
        else:
            print(f"This key {key} isn't available in config.parameters! Thus the default config will maintain.")

    fnnestimator = SimpleFeedForwardEstimator(num_hidden_dimensions=parameters["num_hidden_dimensions"],
                                              prediction_length=parameters["prediction_length"],
                                              context_length=parameters["context_length"],
                                              distr_output=parameters["distr_output"],
                                              batch_size=parameters["batch_size"],
                                              batch_normalization=parameters["batch_normalization"],
                                              trainer=Trainer(epochs=parameters["epochs"],
                                                              num_batches_per_epoch=parameters["num_batches_per_epoch"],
                                                             ),
                                              )
    return fnnestimator

def evaluate(config, train, test, configuration):
    
    fnnestimator = update_FNN_parameters(configuration, config)
    
    predictor = fnnestimator.train(train)
    
    forecast_it, ts_it = make_evaluation_predictions(dataset=test, predictor=predictor,num_samples=100)
    forecasts = list(forecast_it)
    tss = list(ts_it)
    
    # Evaluation with the quantiles of the configuration and calculation of the mean_WIS
    evaluator = Evaluator(quantiles=configuration.quantiles)    
    agg_metrics = evaluator(tss, forecasts)[0]
    mean_WIS = agg_metrics["mean_absolute_QuantileLoss"]/(config["prediction_length"]*411)
    return mean_WIS

def objectiveFNN(config, train, test, configuration):
    score = evaluate(config, train, test, configuration)
    session.report({"mean_WIS":score})

# %%
hp_search_space = {
    "num_hidden_dimensions": tune.grid_search([[5],[10], [20]]),
    "context_length":tune.grid_search([4, 52, 104]),
    "epochs":tune.grid_search([5, 10, 20]),
    "prediction_length" : tune.grid_search([4, 52, 104]), 
    "num_batches_per_epoch":tune.grid_search([25, 50, 100]),
    "batch_normalization":tune.grid_search([True, False]),
    "batch_size":tune.grid_search([20, 32, 64]),
    }




train = data_splits_dict["with_features_2001"][0]
test = data_splits_dict["with_features_2001"][1]
configuration = Configuration()

tuner = tune.Tuner(
    tune.with_parameters(objectiveFNN, train=train, test=test, configuration=configuration),
    tune_config=tune.TuneConfig(
        num_samples = 5,
        metric="mean_WIS",
        mode="min",
        max_concurrent_trials=10,
    ),
    param_space=hp_search_space,
)
results = tuner.fit()

print("Best hyperparameters found were: ", results.get_best_result().config)

results_df = results.get_dataframe()
print(results_df)
results_df.to_csv("FNN_Hyperparameter_results_12_05.csv")
# Out:
# 2023-05-12 18:36:17,852	INFO worker.py:1553 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-12 19:22:58</td></tr>
# <tr><td>Running for: </td><td>00:46:34.65        </td></tr>
# <tr><td>Memory:      </td><td>136.4/236.0 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 10.0/48 CPUs, 0/0 GPUs, 0.0/120.49 GiB heap, 0.0/55.63 GiB objects
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 54 more trials not shown (54 TERMINATED)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc                </th><th>batch_normalization  </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  context_length</th><th style="text-align: right;">  epochs</th><th style="text-align: right;">   num_batches_per_epoc
# h</th><th>num_hidden_dimension
# s    </th><th style="text-align: right;">  prediction_length</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  mean_WIS</th></tr>
# </thead>
# <tbody>
# <tr><td>objectiveFNN_21ea7_00052</td><td>RUNNING   </td><td>172.22.1.197:715699</td><td>True                 </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;">25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00053</td><td>RUNNING   </td><td>172.22.1.197:715707</td><td>False                </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">      20</td><td style="text-align: right;">25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00064</td><td>RUNNING   </td><td>172.22.1.197:715693</td><td>True                 </td><td style="text-align: right;">          64</td><td style="text-align: right;">              52</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00065</td><td>RUNNING   </td><td>172.22.1.197:715598</td><td>False                </td><td style="text-align: right;">          64</td><td style="text-align: right;">              52</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00068</td><td>RUNNING   </td><td>172.22.1.197:715697</td><td>True                 </td><td style="text-align: right;">          32</td><td style="text-align: right;">             104</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00069</td><td>RUNNING   </td><td>172.22.1.197:715701</td><td>False                </td><td style="text-align: right;">          32</td><td style="text-align: right;">             104</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00070</td><td>RUNNING   </td><td>172.22.1.197:715703</td><td>True                 </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00071</td><td>RUNNING   </td><td>172.22.1.197:715705</td><td>False                </td><td style="text-align: right;">          64</td><td style="text-align: right;">             104</td><td style="text-align: right;">       5</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00072</td><td>RUNNING   </td><td>172.22.1.197:715691</td><td>True                 </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">      10</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00073</td><td>RUNNING   </td><td>172.22.1.197:715695</td><td>False                </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">      10</td><td style="text-align: right;">50</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td></tr>
# <tr><td>objectiveFNN_21ea7_00000</td><td>TERMINATED</td><td>172.22.1.197:715598</td><td>True                 </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;">25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         144.652</td><td style="text-align: right;">   717.115</td></tr>
# <tr><td>objectiveFNN_21ea7_00001</td><td>TERMINATED</td><td>172.22.1.197:715691</td><td>False                </td><td style="text-align: right;">          20</td><td style="text-align: right;">               4</td><td style="text-align: right;">       5</td><td style="text-align: right;">25</td><td>[5]</td><td style="text-align: right;">                  4</td><td style="text-align: right;">     1</td><td style="text-align: right;">         147.416</td><td style="text-align: right;">   738.678</td></tr>
# <tr><td>objectiveFNN_21ea7_00002</td><td>TERMINATED</td><td>172.22.1.197:715693</td><td>True
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  44%|████▍     | 11/25 [00:10<00:12,  1.09it/s, epoch=1/5, avg_epoch_loss=1.29]
#  52%|█████▏    | 13/25 [00:10<00:09,  1.28it/s, epoch=1/5, avg_epoch_loss=1.37]
#  52%|█████▏    | 13/25 [00:10<00:09,  1.28it/s, epoch=1/5, avg_epoch_loss=3.59]
#  48%|████▊     | 12/25 [00:10<00:11,  1.18it/s, epoch=1/5, avg_epoch_loss=4.17]
#  32%|███▏      | 8/25 [00:10<00:21,  1.27s/it, epoch=1/5, avg_epoch_loss=1.63]
#  32%|███▏      | 8/25 [00:10<00:21,  1.29s/it, epoch=1/5, avg_epoch_loss=3.69]
#  16%|█▌        | 4/25 [00:10<00:55,  2.63s/it, epoch=1/5, avg_epoch_loss=1.24]
#  36%|███▌      | 9/25 [00:11<00:20,  1.29s/it, epoch=1/5, avg_epoch_loss=1.2]
#  32%|███▏      | 8/25 [00:11<00:23,  1.39s/it, epoch=1/5, avg_epoch_loss=3.94]
#  20%|██        | 5/25 [00:12<00:49,  2.46s/it, epoch=1/5, avg_epoch_loss=1.75]
# 100%|██████████| 25/25 [00:19<00:00,  1.30it/s, epoch=1/5, avg_epoch_loss=1.35]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:17<00:00,  1.40it/s, epoch=1/5, avg_epoch_loss=3.07]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:18<00:00,  1.38it/s, epoch=1/5, avg_epoch_loss=1.27]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:18<00:00,  1.37it/s, epoch=1/5, avg_epoch_loss=3.81]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  80%|████████  | 20/25 [00:20<00:04,  1.01it/s, epoch=1/5, avg_epoch_loss=1.6]
#  40%|████      | 10/25 [00:20<00:30,  2.02s/it, epoch=1/5, avg_epoch_loss=1.27]
#  80%|████████  | 20/25 [00:20<00:05,  1.01s/it, epoch=1/5, avg_epoch_loss=3.82]
#  84%|████████▍ | 21/25 [00:21<00:03,  1.03it/s, epoch=1/5, avg_epoch_loss=3.84]
#  88%|████████▊ | 22/25 [00:22<00:02,  1.04it/s, epoch=1/5, avg_epoch_loss=1.4]
#  52%|█████▏    | 13/25 [00:23<00:20,  1.70s/it, epoch=1/5, avg_epoch_loss=1.59]
# 100%|██████████| 25/25 [00:23<00:00,  1.07it/s, epoch=1/5, avg_epoch_loss=1.62]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:24<00:00,  1.04it/s, epoch=1/5, avg_epoch_loss=1.46]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:23<00:00,  1.05it/s, epoch=1/5, avg_epoch_loss=3.65]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:23<00:00,  1.05it/s, epoch=1/5, avg_epoch_loss=3.7]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.62it/s, epoch=2/5, avg_epoch_loss=1.46]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.68it/s, epoch=2/5, avg_epoch_loss=2.5]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.72it/s, epoch=2/5, avg_epoch_loss=1.37]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.72it/s, epoch=2/5, avg_epoch_loss=2.55]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  80%|████████  | 20/25 [00:31<00:07,  1.45s/it, epoch=1/5, avg_epoch_loss=1.34]
# 100%|██████████| 25/25 [00:08<00:00,  2.82it/s, epoch=3/5, avg_epoch_loss=1.3]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:10<00:03,  1.80it/s, epoch=2/5, avg_epoch_loss=1.24]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.70it/s, epoch=2/5, avg_epoch_loss=2.42]
#  80%|████████  | 20/25 [00:10<00:02,  1.94it/s, epoch=2/5, avg_epoch_loss=1.44]
#  72%|███████▏  | 18/25 [00:10<00:03,  1.77it/s, epoch=2/5, avg_epoch_loss=2.1]
#  92%|█████████▏| 23/25 [00:34<00:02,  1.36s/it, epoch=1/5, avg_epoch_loss=1.59]
# 100%|██████████| 25/25 [00:08<00:00,  2.89it/s, epoch=3/5, avg_epoch_loss=1.64]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:08<00:00,  2.82it/s, epoch=3/5, avg_epoch_loss=1.96]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.67it/s, epoch=3/5, avg_epoch_loss=2.01]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:12<00:00,  1.92it/s, epoch=2/5, avg_epoch_loss=1.47]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:36<00:00,  1.47s/it, epoch=1/5, avg_epoch_loss=1.6]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:13<00:00,  1.83it/s, epoch=2/5, avg_epoch_loss=1.3]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:37<00:00,  1.51s/it, epoch=1/5, avg_epoch_loss=1.34]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:13<00:00,  1.79it/s, epoch=2/5, avg_epoch_loss=2.14]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.68it/s, epoch=2/5, avg_epoch_loss=2.26]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.64it/s, epoch=4/5, avg_epoch_loss=1.51]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:08<00:00,  2.80it/s, epoch=4/5, avg_epoch_loss=1.39]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:08<00:00,  2.79it/s, epoch=4/5, avg_epoch_loss=1.58]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.70it/s, epoch=4/5, avg_epoch_loss=1.73]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:10<00:04,  1.75it/s, epoch=3/5, avg_epoch_loss=1.56]
#  72%|███████▏  | 18/25 [00:10<00:04,  1.71it/s, epoch=3/5, avg_epoch_loss=1.06]
#  40%|████      | 10/25 [00:11<00:16,  1.11s/it, epoch=2/5, avg_epoch_loss=1.67]
#  80%|████████  | 20/25 [00:10<00:02,  1.93it/s, epoch=3/5, avg_epoch_loss=2.17]
#  40%|████      | 10/25 [00:11<00:16,  1.10s/it, epoch=2/5, avg_epoch_loss=1.28]
#  64%|██████▍   | 16/25 [00:10<00:05,  1.59it/s, epoch=3/5, avg_epoch_loss=1.91]
# 100%|██████████| 25/25 [00:13<00:00,  1.92it/s, epoch=3/5, avg_epoch_loss=2.16]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.73it/s, epoch=3/5, avg_epoch_loss=1.68]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.71it/s, epoch=3/5, avg_epoch_loss=1.19]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.66it/s, epoch=5/5, avg_epoch_loss=1.52]
# 100%|██████████| 25/25 [00:15<00:00,  1.64it/s, epoch=3/5, avg_epoch_loss=1.99]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:09<00:00,  2.60it/s, epoch=5/5, avg_epoch_loss=1.63]
# 100%|██████████| 25/25 [00:09<00:00,  2.68it/s, epoch=5/5, avg_epoch_loss=1.91]
# 100%|██████████| 25/25 [00:10<00:00,  2.50it/s, epoch=5/5, avg_epoch_loss=1.63]
#  76%|███████▌  | 19/25 [00:21<00:06,  1.14s/it, epoch=2/5, avg_epoch_loss=1.67]
#  40%|████      | 10/25 [00:22<00:16,  1.10s/it, epoch=2/5, avg_epoch_loss=1.43]
#  80%|████████  | 20/25 [00:22<00:05,  1.16s/it, epoch=2/5, avg_epoch_loss=1.41]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.70it/s, epoch=4/5, avg_epoch_loss=1.47]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.80it/s, epoch=4/5, avg_epoch_loss=1.48]
#  72%|███████▏  | 18/25 [00:10<00:04,  1.74it/s, epoch=4/5, avg_epoch_loss=1.47]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.82it/s, epoch=4/5, avg_epoch_loss=1.87]
# 100%|██████████| 25/25 [00:13<00:00,  1.82it/s, epoch=4/5, avg_epoch_loss=1.52]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.68it/s, epoch=4/5, avg_epoch_loss=1.5]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:29<00:00,  1.17s/it, epoch=2/5, avg_epoch_loss=1.59]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:28<00:00,  1.16s/it, epoch=2/5, avg_epoch_loss=1.39]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.70it/s, epoch=4/5, avg_epoch_loss=1.37]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:13<00:00,  1.83it/s, epoch=4/5, avg_epoch_loss=1.77]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 12/25 [00:11<00:12,  1.04it/s, epoch=5/5, avg_epoch_loss=2.04]
#  36%|███▌      | 9/25 [00:11<00:20,  1.30s/it, epoch=5/5, avg_epoch_loss=1.35]
#  48%|████▊     | 12/25 [00:11<00:12,  1.08it/s, epoch=5/5, avg_epoch_loss=1.29]
#  28%|██▊       | 7/25 [00:11<00:30,  1.71s/it, epoch=3/5, avg_epoch_loss=1.45]
#  28%|██▊       | 7/25 [00:11<00:28,  1.60s/it, epoch=5/5, avg_epoch_loss=1.4]
# Running evaluation: 0it [00:00, ?it/s]
#  20%|██        | 5/25 [00:14<00:57,  2.90s/it, epoch=3/5, avg_epoch_loss=1.09]
# Running evaluation: 41922it [00:02, 16671.31it/s]
# Running evaluation: 0it [00:00, ?it/s]
# Running evaluation: 0it [00:00, ?it/s]
#  36%|███▌      | 9/25 [00:23<00:20,  1.30s/it, epoch=5/5, avg_epoch_loss=1.62]
# Running evaluation: 41922it [00:06, 6919.46it/s]
#  60%|██████    | 15/25 [00:22<00:14,  1.47s/it, epoch=5/5, avg_epoch_loss=1.49]
#  48%|████▊     | 12/25 [00:25<00:12,  1.04it/s, epoch=5/5, avg_epoch_loss=1.71]
#  28%|██▊       | 7/25 [00:24<00:30,  1.71s/it, epoch=3/5, avg_epoch_loss=1.38]
#  84%|████████▍ | 21/25 [00:25<00:05,  1.28s/it, epoch=5/5, avg_epoch_loss=1.68]
#  48%|████▊     | 12/25 [00:23<00:12,  1.08it/s, epoch=5/5, avg_epoch_loss=1.27]
#  68%|██████▊   | 17/25 [00:24<00:11,  1.45s/it, epoch=5/5, avg_epoch_loss=1.61]
# Running evaluation: 0it [00:00, ?it/s]
#  84%|████████▍ | 21/25 [00:24<00:04,  1.21s/it, epoch=5/5, avg_epoch_loss=1.27]
#  36%|███▌      | 9/25 [00:25<00:44,  2.77s/it, epoch=3/5, avg_epoch_loss=1.22]
# Running evaluation: 41922it [00:01, 21746.06it/s]
# Running evaluation: 41922it [00:05, 7027.77it/s]
#  48%|████▊     | 12/25 [00:27<00:31,  2.44s/it, epoch=3/5, avg_epoch_loss=1.36]
# 100%|██████████| 25/25 [00:33<00:00,  1.33s/it, epoch=5/5, avg_epoch_loss=1.74]
#  60%|██████    | 15/25 [00:32<00:14,  1.47s/it, epoch=5/5, avg_epoch_loss=1.59]
#  88%|████████▊ | 22/25 [00:33<00:04,  1.50s/it, epoch=5/5, avg_epoch_loss=1.63]
#  96%|█████████▌| 24/25 [00:39<00:01,  1.75s/it, epoch=5/5, avg_epoch_loss=1.6]
# 100%|██████████| 25/25 [00:40<00:00,  1.60s/it, epoch=5/5, avg_epoch_loss=1.28]
# 100%|██████████| 25/25 [00:39<00:00,  1.60s/it, epoch=5/5, avg_epoch_loss=1.64]
# 100%|██████████| 25/25 [00:41<00:00,  1.68s/it, epoch=5/5, avg_epoch_loss=1.61]
#  36%|███▌      | 9/25 [00:43<00:44,  2.77s/it, epoch=3/5, avg_epoch_loss=1.26]
#  48%|████▊     | 12/25 [00:44<00:31,  2.44s/it, epoch=3/5, avg_epoch_loss=1.39]
#  56%|█████▌    | 14/25 [00:46<00:43,  3.99s/it, epoch=3/5, avg_epoch_loss=1.39]
#  52%|█████▏    | 13/25 [00:45<00:45,  3.82s/it, epoch=3/5, avg_epoch_loss=1.23]
#  60%|██████    | 15/25 [00:56<00:41,  4.20s/it, epoch=3/5, avg_epoch_loss=1.24]
# (objectiveFNN pid=715701) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715701)   return arr.astype(dtype, copy=True)
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name              </th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>experiment_tag                                                                                                                              </th><th>hostname      </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">  mean_WIS</th><th>node_ip     </th><th style="text-align: right;">   pid</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>objectiveFNN_21ea7_00000</td><td>2023-05-12_18-38-52</td><td>True  </td><td>                </td><td>b7c681a606d54d8586222bf5b5fa79cf</td><td>0_batch_normalization=True,batch_size=20,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   717.115</td><td>172.22.1.197</td><td style="text-align: right;">715598</td><td style="text-align: right;">             144.652</td><td style="text-align: right;">           144.652</td><td style="text-align: right;">       144.652</td><td style="text-align: right;"> 1683909532</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00000</td><td style="text-align: right;">   0.00603008</td></tr>
# <tr><td>objectiveFNN_21ea7_00001</td><td>2023-05-12_18-38-59</td><td>True  </td><td>                </td><td>882278c1249e49b6b46f579a4e0b1947</td><td>1_batch_normalization=False,batch_size=20,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4    </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   738.678</td><td>172.22.1.197</td><td style="text-align: right;">715691</td><td style="text-align: right;">             147.416</td><td style="text-align: right;">           147.416</td><td style="text-align: right;">       147.416</td><td style="text-align: right;"> 1683909539</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00001</td><td style="text-align: right;">   0.00529432</td></tr>
# <tr><td>objectiveFNN_21ea7_00002</td><td>2023-05-12_18-39-47</td><td>True  </td><td>                </td><td>b3df4ced9a844ba8a972a507f064e3f8</td><td>2_batch_normalization=True,batch_size=32,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   782.791</td><td>172.22.1.197</td><td style="text-align: right;">715693</td><td style="text-align: right;">             195.145</td><td style="text-align: right;">           195.145</td><td style="text-align: right;">       195.145</td><td style="text-align: right;"> 1683909587</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00002</td><td style="text-align: right;">   0.00548911</td></tr>
# <tr><td>objectiveFNN_21ea7_00003</td><td>2023-05-12_18-40-03</td><td>True  </td><td>                </td><td>f3bea6905c434efea152c74b93670117</td><td>3_batch_normalization=False,batch_size=32,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4    </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   756.077</td><td>172.22.1.197</td><td style="text-align: right;">715695</td><td style="text-align: right;">             211.043</td><td style="text-align: right;">           211.043</td><td style="text-align: right;">       211.043</td><td style="text-align: right;"> 1683909603</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00003</td><td style="text-align: right;">   0.00589633</td></tr>
# <tr><td>objectiveFNN_21ea7_00004</td><td>2023-05-12_18-41-33</td><td>True  </td><td>                </td><td>4e3ff4e32ca748288ab5b32e8c01e3c8</td><td>4_batch_normalization=True,batch_size=64,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4     </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   730.252</td><td>172.22.1.197</td><td style="text-align: right;">715697</td><td style="text-align: right;">             301.106</td><td style="text-align: right;">           301.106</td><td style="text-align: right;">       301.106</td><td style="text-align: right;"> 1683909693</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00004</td><td style="text-align: right;">   0.00532126</td></tr>
# <tr><td>objectiveFNN_21ea7_00005</td><td>2023-05-12_18-42-01</td><td>True  </td><td>                </td><td>5187ca9dc20a4901a77de82e75725891</td><td>5_batch_normalization=False,batch_size=64,context_length=4,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4    </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   742.673</td><td>172.22.1.197</td><td style="text-align: right;">715699</td><td style="text-align: right;">             328.852</td><td style="text-align: right;">           328.852</td><td style="text-align: right;">       328.852</td><td style="text-align: right;"> 1683909721</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00005</td><td style="text-align: right;">   0.00515485</td></tr>
# <tr><td>objectiveFNN_21ea7_00006</td><td>2023-05-12_18-38-40</td><td>True  </td><td>                </td><td>206cd563d601411ca82066a9431102fa</td><td>6_batch_normalization=True,batch_size=20,context_length=52,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4    </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   779.026</td><td>172.22.1.197</td><td style="text-align: right;">715701</td><td style="text-align: right;">             127.671</td><td style="text-align: right;">           127.671</td><td style="text-align: right;">       127.671</td><td style="text-align: right;"> 1683909520</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>21ea7_00006</td><td style="text-align: right;">   0.00483036</td></tr>
# <tr><td>objectiveFNN_21ea7_00007</td><td>2023-05-12_18-38-59</td><td>True  </td><td>                </td><td>89b700de0de449c5b80a343324a93315</td><td>7_batch_normalization=False,batch_size=20,context_length=52,epochs=5,num_batches_per_epoch=25,num_hidden_dimensions=5,prediction_length=4   </td><td>econ-stat-rr01</td><td style="text-align: right;">                         1</td><td style="text-align: right;">   805.93 </td><td>172.22.1.197</td><td style="text-align: right;">715703</td><td style="text-align: right;">             146.523</td><td style="text-align: right;">           146.523</td>
#   0%|          | 0/25 [00:00<?, ?it/s]
#  56%|█████▌    | 14/25 [01:04<00:43,  3.99s/it, epoch=3/5, avg_epoch_loss=1.37]
#  64%|██████▍   | 16/25 [01:07<00:50,  5.60s/it, epoch=3/5, avg_epoch_loss=1.36]
#  72%|███████▏  | 18/25 [01:07<00:27,  3.97s/it, epoch=3/5, avg_epoch_loss=1.27]
# (objectiveFNN pid=715598) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715598)   return arr.astype(dtype, copy=True)
#   8%|▊         | 2/25 [00:11<02:07,  5.52s/it, epoch=1/5, avg_epoch_loss=4.44]
#   0%|          | 0/25 [00:00<?, ?it/s]
# (objectiveFNN pid=715703) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715703)   return arr.astype(dtype, copy=True)
#  72%|███████▏  | 18/25 [01:18<00:38,  5.53s/it, epoch=3/5, avg_epoch_loss=1.32]
# (objectiveFNN pid=715691) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715691)   return arr.astype(dtype, copy=True)
#  88%|████████▊ | 22/25 [01:18<00:10,  3.51s/it, epoch=3/5, avg_epoch_loss=1.3]
# Running evaluation: 0it [00:00, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Running evaluation: 41922it [00:01, 26225.08it/s]
#   8%|▊         | 2/25 [00:21<02:07,  5.52s/it, epoch=1/5, avg_epoch_loss=3.74]
#  20%|██        | 5/25 [00:21<01:23,  4.19s/it, epoch=1/5, avg_epoch_loss=4.17]
# Running evaluation: 0it [00:00, ?it/s]
# Running evaluation: 0it [00:00, ?it/s]
# 100%|██████████| 25/25 [01:25<00:00,  3.43s/it, epoch=3/5, avg_epoch_loss=1.31]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  12%|█▏        | 3/25 [00:11<01:21,  3.72s/it, epoch=1/5, avg_epoch_loss=4.16]
#  96%|█████████▌| 24/25 [01:28<00:03,  3.56s/it, epoch=3/5, avg_epoch_loss=1.29]
# Running evaluation: 41922it [00:05, 7926.30it/s]
#  32%|███▏      | 8/25 [00:10<00:21,  1.26s/it, epoch=1/5, avg_epoch_loss=2.82]
# 100%|██████████| 25/25 [01:31<00:00,  3.65s/it, epoch=3/5, avg_epoch_loss=1.29]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Running evaluation: 41922it [00:06, 6642.20it/s]
#  32%|███▏      | 8/25 [00:11<00:24,  1.43s/it, epoch=1/5, avg_epoch_loss=4.67]
#  20%|██        | 5/25 [00:32<01:23,  4.19s/it, epoch=1/5, avg_epoch_loss=4.33]
#  28%|██▊       | 7/25 [00:34<01:29,  4.98s/it, epoch=1/5, avg_epoch_loss=4.25]
#   8%|▊         | 2/25 [00:12<02:18,  6.02s/it, epoch=4/5, avg_epoch_loss=1.3]
#  12%|█▏        | 3/25 [00:22<01:21,  3.72s/it, epoch=1/5, avg_epoch_loss=4.78]
#  20%|██        | 5/25 [00:22<01:34,  4.73s/it, epoch=1/5, avg_epoch_loss=5.18]
# Running evaluation: 0it [00:00, ?it/s]
#  32%|███▏      | 8/25 [00:23<00:21,  1.26s/it, epoch=1/5, avg_epoch_loss=2.82]
#  32%|███▏      | 8/25 [00:23<00:24,  1.43s/it, epoch=1/5, avg_epoch_loss=5.81]
#  48%|████▊     | 12/25 [00:23<00:26,  2.06s/it, epoch=1/5, avg_epoch_loss=5.82]
#  12%|█▏        | 3/25 [00:13<01:40,  4.55s/it, epoch=4/5, avg_epoch_loss=1.64]
#  60%|██████    | 15/25 [00:25<00:17,  1.78s/it, epoch=1/5, avg_epoch_loss=5.89]
# Running evaluation: 41922it [00:05, 6997.29it/s]
#  16%|█▌        | 4/25 [00:22<01:54,  5.46s/it, epoch=4/5, avg_epoch_loss=1.32]
#  40%|████      | 10/25 [00:47<01:11,  4.74s/it, epoch=1/5, avg_epoch_loss=4.27]
# (objectiveFNN pid=715707) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715707)   return arr.astype(dtype, copy=True)
#   0%|          | 0/25 [00:00<?, ?it/s]
#  28%|██▊       | 7/25 [00:41<02:01,  6.74s/it, epoch=1/5, avg_epoch_loss=4.87]
#  64%|██████▍   | 16/25 [00:38<00:24,  2.68s/it, epoch=1/5, avg_epoch_loss=5.57]
#  24%|██▍       | 6/25 [00:31<01:43,  5.45s/it, epoch=4/5, avg_epoch_loss=1.72]
#  28%|██▊       | 7/25 [00:37<01:35,  5.31s/it, epoch=4/5, avg_epoch_loss=1.39]
#  60%|██████    | 15/25 [00:43<00:17,  1.78s/it, epoch=1/5, avg_epoch_loss=5.28]
#  52%|█████▏    | 13/25 [01:02<00:57,  4.81s/it, epoch=1/5, avg_epoch_loss=4.28]
#  80%|████████  | 20/25 [00:44<00:12,  2.54s/it, epoch=1/5, avg_epoch_loss=5.23]
# (objectiveFNN pid=715693) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715693)   return arr.astype(dtype, copy=True)
#  12%|█▏        | 3/25 [00:11<01:24,  3.84s/it, epoch=1/5, avg_epoch_loss=4.99]
#  28%|██▊       | 7/25 [00:52<02:01,  6.74s/it, epoch=1/5, avg_epoch_loss=4.59]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  80%|████████  | 20/25 [00:49<00:13,  2.75s/it, epoch=1/5, avg_epoch_loss=6.91]
#  40%|████      | 10/25 [00:54<01:22,  5.51s/it, epoch=1/5, avg_epoch_loss=4.67]
# 100%|██████████| 25/25 [00:51<00:00,  2.07s/it, epoch=1/5, avg_epoch_loss=4.74]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  28%|██▊       | 7/25 [00:47<01:35,  5.31s/it, epoch=4/5, avg_epoch_loss=1.34]
#  24%|██▍       | 6/25 [00:43<01:43,  5.45s/it, epoch=4/5, avg_epoch_loss=1.61]
#  52%|█████▏    | 13/25 [01:12<00:57,  4.81s/it, epoch=1/5, avg_epoch_loss=4.09]
#  44%|████▍     | 11/25 [00:48<00:56,  4.01s/it, epoch=4/5, avg_epoch_loss=1.37]
#  68%|██████▊   | 17/25 [01:13<00:31,  3.91s/it, epoch=1/5, avg_epoch_loss=4.01]
#  32%|███▏      | 8/25 [00:45<01:39,  5.86s/it, epoch=4/5, avg_epoch_loss=1.55]
#  28%|██▊       | 7/25 [00:22<00:55,  3.06s/it, epoch=1/5, avg_epoch_loss=3.15]
# (objectiveFNN pid=715705) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715705)   return arr.astype(dtype, copy=True)
# 100%|██████████| 25/25 [00:57<00:00,  2.31s/it, epoch=1/5, avg_epoch_loss=6.45]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  16%|█▌        | 4/25 [00:10<00:54,  2.58s/it, epoch=1/5, avg_epoch_loss=3.39]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  56%|█████▌    | 14/25 [01:05<00:46,  4.22s/it, epoch=1/5, avg_epoch_loss=4.34]
#  44%|████▍     | 11/25 [00:10<00:13,  1.05it/s, epoch=2/5, avg_epoch_loss=4.24]
# (objectiveFNN pid=715695) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715695)   return arr.astype(dtype, copy=True)
#   0%|          | 0/25 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:59<00:18,  2.62s/it, epoch=4/5, avg_epoch_loss=1.3]
#  92%|█████████▏| 23/25 [01:23<00:05,  2.86s/it, epoch=1/5, avg_epoch_loss=3.65]
#  56%|█████▌    | 14/25 [00:56<00:37,  3.43s/it, epoch=4/5, avg_epoch_loss=1.45]
# 100%|██████████| 25/25 [00:15<00:00,  1.63it/s, epoch=2/5, avg_epoch_loss=3.43]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [01:25<00:00,  3.43s/it, epoch=1/5, avg_epoch_loss=3.6]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  96%|█████████▌| 24/25 [00:10<00:00,  2.37it/s, epoch=2/5, avg_epoch_loss=4.56]
# 100%|██████████| 25/25 [00:10<00:00,  2.39it/s, epoch=2/5, avg_epoch_loss=4.42]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  68%|██████▊   | 17/25 [00:32<00:13,  1.67s/it, epoch=1/5, avg_epoch_loss=2.7]
#  52%|█████▏    | 13/25 [00:21<00:18,  1.55s/it, epoch=1/5, avg_epoch_loss=3.97]
#  16%|█▌        | 4/25 [00:10<00:56,  2.71s/it, epoch=1/5, avg_epoch_loss=3.7]
#  88%|████████▊ | 22/25 [01:15<00:07,  2.54s/it, epoch=1/5, avg_epoch_loss=3.87]
# 100%|██████████| 25/25 [01:07<00:00,  2.69s/it, epoch=4/5, avg_epoch_loss=1.33]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:37<00:00,  1.50s/it, epoch=1/5, avg_epoch_loss=2.93]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [01:19<00:00,  3.18s/it, epoch=1/5, avg_epoch_loss=3.73]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  20%|██        | 5/25 [00:11<00:46,  2.31s/it, epoch=1/5, avg_epoch_loss=8.27]
#  92%|█████████▏| 23/25 [01:06<00:04,  2.15s/it, epoch=4/5, avg_epoch_loss=1.39]
# 100%|██████████| 25/25 [00:10<00:00,  2.45it/s, epoch=3/5, avg_epoch_loss=2.91]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:27<00:00,  1.12s/it, epoch=1/5, avg_epoch_loss=4.36]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  36%|███▌      | 9/25 [00:10<00:17,  1.12s/it, epoch=2/5, avg_epoch_loss=2.78]
# 100%|██████████| 25/25 [00:09<00:00,  2.72it/s, epoch=3/5, avg_epoch_loss=3.07]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [01:08<00:00,  2.75s/it, epoch=4/5, avg_epoch_loss=1.36]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  40%|████      | 10/25 [00:21<00:31,  2.10s/it, epoch=1/5, avg_epoch_loss=4.15]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.69it/s, epoch=2/5, avg_epoch_loss=4.01]
#  40%|████      | 10/25 [00:10<00:16,  1.07s/it, epoch=5/5, avg_epoch_loss=1.22]
# 100%|██████████| 25/25 [00:08<00:00,  2.95it/s, epoch=4/5, avg_epoch_loss=2.02]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  36%|███▌      | 9/25 [00:10<00:19,  1.20s/it, epoch=2/5, avg_epoch_loss=2.87]
#  52%|█████▏    | 13/25 [00:22<00:19,  1.64s/it, epoch=1/5, avg_epoch_loss=5.02]
# 100%|██████████| 25/25 [00:09<00:00,  2.64it/s, epoch=4/5, avg_epoch_loss=2.3]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.84it/s, epoch=2/5, avg_epoch_loss=3.84]
# 100%|██████████| 25/25 [00:14<00:00,  1.70it/s, epoch=2/5, avg_epoch_loss=3.38]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:20<00:08,  1.15s/it, epoch=2/5, avg_epoch_loss=2.63]
#  36%|███▌      | 9/25 [00:10<00:18,  1.16s/it, epoch=5/5, avg_epoch_loss=1.31]
# 100%|██████████| 25/25 [00:13<00:00,  1.89it/s, epoch=2/5, avg_epoch_loss=3.77]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  76%|███████▌  | 19/25 [00:32<00:09,  1.55s/it, epoch=1/5, avg_epoch_loss=4.08]
# 100%|██████████| 25/25 [00:08<00:00,  2.88it/s, epoch=5/5, avg_epoch_loss=1.84]
#  80%|████████  | 20/25 [00:22<00:05,  1.11s/it, epoch=5/5, avg_epoch_loss=1.34]
# 100%|██████████| 25/25 [00:28<00:00,  1.13s/it, epoch=2/5, avg_epoch_loss=2.43]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  88%|████████▊ | 22/25 [00:32<00:04,  1.39s/it, epoch=1/5, avg_epoch_loss=4.11]
# 100%|██████████| 25/25 [00:10<00:00,  2.49it/s, epoch=5/5, avg_epoch_loss=4.17]
#  72%|███████▏  | 18/25 [00:22<00:08,  1.23s/it, epoch=2/5, avg_epoch_loss=2.58]
#  60%|██████    | 15/25 [00:10<00:06,  1.49it/s, epoch=3/5, avg_epoch_loss=2.6]
# 100%|██████████| 25/25 [00:38<00:00,  1.56s/it, epoch=1/5, avg_epoch_loss=3.93]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:21<00:08,  1.17s/it, epoch=5/5, avg_epoch_loss=1.17]
# 100%|██████████| 25/25 [00:36<00:00,  1.45s/it, epoch=1/5, avg_epoch_loss=4.14]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:27<00:00,  1.12s/it, epoch=5/5, avg_epoch_loss=1.29]
#  68%|██████▊   | 17/25 [00:10<00:05,  1.59it/s, epoch=3/5, avg_epoch_loss=2.23]
# 100%|██████████| 25/25 [00:16<00:00,  1.49it/s, epoch=3/5, avg_epoch_loss=2.38]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:15<00:00,  1.62it/s, epoch=3/5, avg_epoch_loss=2.28]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:30<00:00,  1.22s/it, epoch=2/5, avg_epoch_loss=2.48]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  36%|███▌      | 9/25 [00:10<00:18,  1.18s/it, epoch=3/5, avg_epoch_loss=1.65]
# 100%|██████████| 25/25 [00:29<00:00,  1.16s/it, epoch=5/5, avg_epoch_loss=1.23]
#  36%|███▌      | 9/25 [00:10<00:19,  1.20s/it, epoch=2/5, avg_epoch_loss=3.22]
#  36%|███▌      | 9/25 [00:10<00:19,  1.19s/it, epoch=2/5, avg_epoch_loss=2.59]
#  68%|██████▊   | 17/25 [00:10<00:04,  1.70it/s, epoch=4/5, avg_epoch_loss=2.67]
#  76%|███████▌  | 19/25 [00:10<00:03,  1.84it/s, epoch=4/5, avg_epoch_loss=1.94]
#  36%|███▌      | 9/25 [00:10<00:18,  1.15s/it, epoch=3/5, avg_epoch_loss=1.53]
#  76%|███████▌  | 19/25 [00:21<00:06,  1.13s/it, epoch=3/5, avg_epoch_loss=1.69]
# Running evaluation: 0it [00:00, ?it/s]
# 100%|██████████| 25/25 [00:14<00:00,  1.70it/s, epoch=4/5, avg_epoch_loss=2.45]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:13<00:00,  1.83it/s, epoch=4/5, avg_epoch_loss=1.82]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Running evaluation: 0it [00:00, ?it/s]
# Running evaluation: 41922it [00:02, 20001.05it/s]
# Running evaluation: 41922it [00:01, 24118.23it/s]
#  72%|███████▏  | 18/25 [00:20<00:08,  1.16s/it, epoch=2/5, avg_epoch_loss=2.8]
#  72%|███████▏  | 18/25 [00:22<00:08,  1.26s/it, epoch=2/5, avg_epoch_loss=3.09]
# Running evaluation: 0it [00:00, ?it/s]
#  36%|███▌      | 9/25 [00:22<00:18,  1.15s/it, epoch=3/5, avg_epoch_loss=1.7]
#  28%|██▊       | 7/25 [00:10<00:25,  1.44s/it, epoch=5/5, avg_epoch_loss=1.91]
#  32%|███▏      | 8/25 [00:11<00:24,  1.46s/it, epoch=5/5, avg_epoch_loss=1.25]
#  60%|██████    | 15/25 [00:26<00:19,  1.91s/it, epoch=3/5, avg_epoch_loss=1.7]
# Running evaluation: 41922it [00:08, 4980.82it/s]
#  72%|███████▏  | 18/25 [00:33<00:08,  1.26s/it, epoch=2/5, avg_epoch_loss=3.08]
#  72%|███████▏  | 18/25 [00:33<00:08,  1.16s/it, epoch=2/5, avg_epoch_loss=2.71]
#  76%|███████▌  | 19/25 [00:38<00:06,  1.13s/it, epoch=3/5, avg_epoch_loss=1.62]
#  84%|████████▍ | 21/25 [00:35<00:07,  2.00s/it, epoch=2/5, avg_epoch_loss=2.64]
#  84%|████████▍ | 21/25 [00:38<00:08,  2.17s/it, epoch=2/5, avg_epoch_loss=2.98]
# 100%|██████████| 25/25 [00:44<00:00,  1.79s/it, epoch=3/5, avg_epoch_loss=1.61]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Running evaluation: 0it [00:00, ?it/s]
#  32%|███▏      | 8/25 [00:23<00:24,  1.46s/it, epoch=5/5, avg_epoch_loss=1.29]
#  56%|█████▌    | 14/25 [00:23<00:19,  1.75s/it, epoch=5/5, avg_epoch_loss=1.29]
#  28%|██▊       | 7/25 [00:24<00:25,  1.44s/it, epoch=5/5, avg_epoch_loss=1.76]
#  52%|█████▏    | 13/25 [00:24<00:23,  2.00s/it, epoch=5/5, avg_epoch_loss=1.76]
#  60%|██████    | 15/25 [00:42<00:19,  1.91s/it, epoch=3/5, avg_epoch_loss=1.78]
#  72%|███████▏  | 18/25 [00:44<00:20,  2.93s/it, epoch=3/5, avg_epoch_loss=1.73]
# Running evaluation: 41922it [00:09, 4397.38it/s]
#  92%|█████████▏| 23/25 [00:51<00:05,  2.86s/it, epoch=2/5, avg_epoch_loss=2.83]
# (objectiveFNN pid=715697) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715697)   return arr.astype(dtype, copy=True)
#   8%|▊         | 2/25 [00:11<02:15,  5.89s/it, epoch=4/5, avg_epoch_loss=2.11]
#  92%|█████████▏| 23/25 [00:51<00:06,  3.03s/it, epoch=2/5, avg_epoch_loss=2.91]
#  80%|████████  | 20/25 [00:34<00:08,  1.79s/it, epoch=5/5, avg_epoch_loss=1.43]
#  72%|███████▏  | 18/25 [00:35<00:14,  2.06s/it, epoch=5/5, avg_epoch_loss=1.66]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:56<00:00,  2.26s/it, epoch=2/5, avg_epoch_loss=2.8]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:42<00:00,  1.71s/it, epoch=5/5, avg_epoch_loss=1.48]
#  88%|████████▊ | 22/25 [00:56<00:08,  2.95s/it, epoch=3/5, avg_epoch_loss=1.74]
#  92%|█████████▏| 23/25 [01:03<00:06,  3.03s/it, epoch=2/5, avg_epoch_loss=2.83]
#   8%|▊         | 2/25 [00:23<02:15,  5.89s/it, epoch=4/5, avg_epoch_loss=1.82]
# 100%|██████████| 25/25 [00:46<00:00,  1.87s/it, epoch=5/5, avg_epoch_loss=1.5]
#  24%|██▍       | 6/25 [00:10<00:34,  1.81s/it, epoch=1/10, avg_epoch_loss=1.23]
# (objectiveFNN pid=715703) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715703)   return arr.astype(dtype, copy=True)
# 100%|██████████| 25/25 [01:06<00:00,  2.66s/it, epoch=2/5, avg_epoch_loss=2.77]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  16%|█▌        | 4/25 [00:26<02:24,  6.89s/it, epoch=4/5, avg_epoch_loss=1.83]
#  12%|█▏        | 3/25 [00:13<01:41,  4.63s/it, epoch=3/5, avg_epoch_loss=10.4]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [01:08<00:00,  2.72s/it, epoch=3/5, avg_epoch_loss=1.74]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  52%|█████▏    | 13/25 [00:22<00:21,  1.76s/it, epoch=1/10, avg_epoch_loss=1.3]
#   8%|▊         | 2/25 [00:12<02:18,  6.03s/it, epoch=3/5, avg_epoch_loss=1.94]
#  24%|██▍       | 6/25 [00:39<02:03,  6.52s/it, epoch=4/5, avg_epoch_loss=1.83]
# (objectiveFNN pid=715699) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715699)   return arr.astype(dtype, copy=True)
# (objectiveFNN pid=715691) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715691)   return arr.astype(dtype, copy=True)
#  24%|██▍       | 6/25 [00:24<01:14,  3.90s/it, epoch=3/5, avg_epoch_loss=6.2]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:10<00:22,  1.30s/it, epoch=1/10, avg_epoch_loss=1.95]
#  24%|██▍       | 6/25 [00:10<00:34,  1.82s/it, epoch=4/5, avg_epoch_loss=1.46]
# 100%|██████████| 25/25 [00:31<00:00,  1.27s/it, epoch=1/10, avg_epoch_loss=1.6]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  44%|████▍     | 11/25 [00:22<00:25,  1.83s/it, epoch=3/5, avg_epoch_loss=2]
#  60%|██████    | 15/25 [00:49<00:25,  2.51s/it, epoch=4/5, avg_epoch_loss=1.76]
#  60%|██████    | 15/25 [00:34<00:19,  1.91s/it, epoch=3/5, avg_epoch_loss=3.71]
# Running evaluation: 0it [00:00, ?it/s]
#  32%|███▏      | 8/25 [00:10<00:23,  1.36s/it, epoch=1/10, avg_epoch_loss=1.05]
#  32%|███▏      | 8/25 [00:11<00:23,  1.38s/it, epoch=1/10, avg_epoch_loss=1.42]
#  84%|████████▍ | 21/25 [00:20<00:03,  1.07it/s, epoch=1/10, avg_epoch_loss=1.56]
# Running evaluation: 41922it [00:02, 18843.27it/s]
# 100%|██████████| 25/25 [00:22<00:00,  1.12it/s, epoch=1/10, avg_epoch_loss=1.48]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  60%|██████    | 15/25 [00:21<00:13,  1.37s/it, epoch=4/5, avg_epoch_loss=1.55]
# Running evaluation: 0it [00:00, ?it/s]
# 100%|██████████| 25/25 [00:10<00:00,  2.38it/s, epoch=2/10, avg_epoch_loss=1.36]
#   0%|          | 0/25 [00:00<?, ?it/s]
# Running evaluation: 41922it [00:04, 8618.81it/s]
#  32%|███▏      | 8/25 [00:21<00:23,  1.38s/it, epoch=1/10, avg_epoch_loss=1.62]
#  56%|█████▌    | 14/25 [00:21<00:17,  1.56s/it, epoch=1/10, avg_epoch_loss=1.58]
#  60%|██████    | 15/25 [00:47<00:19,  1.91s/it, epoch=3/5, avg_epoch_loss=3.17]
#  44%|████▍     | 11/25 [00:36<00:25,  1.83s/it, epoch=3/5, avg_epoch_loss=2.19]
#  64%|██████▍   | 16/25 [00:21<00:12,  1.37s/it, epoch=1/10, avg_epoch_loss=1.41]
#  80%|████████  | 20/25 [00:36<00:08,  1.70s/it, epoch=3/5, avg_epoch_loss=2.2]
#  60%|██████    | 15/25 [01:03<00:25,  2.51s/it, epoch=4/5, avg_epoch_loss=1.7]
#  92%|█████████▏| 23/25 [00:48<00:03,  1.87s/it, epoch=3/5, avg_epoch_loss=3.09]
#  96%|█████████▌| 24/25 [01:04<00:02,  2.09s/it, epoch=4/5, avg_epoch_loss=1.71]
#  64%|██████▍   | 16/25 [00:10<00:05,  1.57it/s, epoch=2/10, avg_epoch_loss=1.45]
# 100%|██████████| 25/25 [01:06<00:00,  2.68s/it, epoch=4/5, avg_epoch_loss=1.7]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:11<00:23,  1.41s/it, epoch=3/10, avg_epoch_loss=1.25]
#  60%|██████    | 15/25 [00:34<00:13,  1.37s/it, epoch=4/5, avg_epoch_loss=1.56]
# 100%|██████████| 25/25 [00:53<00:00,  2.12s/it, epoch=3/5, avg_epoch_loss=3.23]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  84%|████████▍ | 21/25 [00:36<00:07,  1.80s/it, epoch=4/5, avg_epoch_loss=1.58]
# 100%|██████████| 25/25 [00:16<00:00,  1.50it/s, epoch=2/10, avg_epoch_loss=1.64]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  92%|█████████▏| 23/25 [00:31<00:02,  1.35s/it, epoch=1/10, avg_epoch_loss=1.6]
# 100%|██████████| 25/25 [00:33<00:00,  1.33s/it, epoch=1/10, avg_epoch_loss=1.47]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:48<00:00,  1.95s/it, epoch=3/5, avg_epoch_loss=2.09]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:33<00:00,  1.36s/it, epoch=1/10, avg_epoch_loss=1.57]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  20%|██        | 5/25 [00:11<00:45,  2.28s/it, epoch=5/5, avg_epoch_loss=1.42]
#  16%|█▌        | 4/25 [00:10<00:57,  2.74s/it, epoch=4/5, avg_epoch_loss=1.58]
#  48%|████▊     | 12/25 [00:10<00:10,  1.20it/s, epoch=3/10, avg_epoch_loss=1.56]
# 100%|██████████| 25/25 [00:47<00:00,  1.91s/it, epoch=4/5, avg_epoch_loss=1.64]
#   0%|          | 0/25 [00:00<?, ?it/s]
# (objectiveFNN pid=715693) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715693)   return arr.astype(dtype, copy=True)
#  32%|███▏      | 8/25 [00:26<00:23,  1.41s/it, epoch=3/10, avg_epoch_loss=1.34]
#  64%|██████▍   | 16/25 [00:27<00:16,  1.78s/it, epoch=3/10, avg_epoch_loss=1.37]
#  36%|███▌      | 9/25 [00:10<00:18,  1.18s/it, epoch=2/10, avg_epoch_loss=1.15]
#  20%|██        | 5/25 [00:11<00:44,  2.21s/it, epoch=4/5, avg_epoch_loss=1.8]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  40%|████      | 10/25 [00:11<00:16,  1.10s/it, epoch=2/10, avg_epoch_loss=1.56]
#  40%|████      | 10/25 [00:22<00:32,  2.20s/it, epoch=5/5, avg_epoch_loss=1.5]
# 100%|██████████| 25/25 [00:18<00:00,  1.39it/s, epoch=3/10, avg_epoch_loss=1.44]
#   0%|          | 0/25 [00:00<?, ?it/s]
# (objectiveFNN pid=715707) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# ...
# (objectiveFNN pid=715691) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715691)   return arr.astype(dtype, copy=True)
# 100%|██████████| 50/50 [01:02<00:00,  1.26s/it, epoch=1/5, avg_epoch_loss=4.25]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  24%|██▍       | 12/50 [00:10<00:32,  1.18it/s, epoch=2/5, avg_epoch_loss=2.33]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  72%|███████▏  | 18/25 [00:33<00:13,  1.86s/it, epoch=17/20, avg_epoch_loss=1.17]
#  34%|███▍      | 17/50 [00:42<01:14,  2.25s/it, epoch=1/5, avg_epoch_loss=4.34]
#  34%|███▍      | 17/50 [00:33<01:02,  1.90s/it, epoch=4/5, avg_epoch_loss=1.29]
#  96%|█████████▌| 24/25 [01:22<00:02,  2.82s/it, epoch=17/20, avg_epoch_loss=1.01]
# 100%|██████████| 25/25 [01:22<00:00,  3.32s/it, epoch=17/20, avg_epoch_loss=0.998]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [02:14<00:00,  2.70s/it, epoch=3/5, avg_epoch_loss=1.45]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  30%|███       | 15/50 [00:10<00:23,  1.48it/s, epoch=2/5, avg_epoch_loss=2.08]
#  36%|███▌      | 18/50 [00:43<01:07,  2.11s/it, epoch=1/5, avg_epoch_loss=4.1]
#  22%|██▏       | 11/50 [00:10<00:35,  1.08it/s, epoch=1/10, avg_epoch_loss=1.42]
#  54%|█████▍    | 27/50 [00:20<00:17,  1.32it/s, epoch=2/5, avg_epoch_loss=2.07]
# 100%|██████████| 25/25 [00:43<00:00,  1.74s/it, epoch=17/20, avg_epoch_loss=1.09]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  48%|████▊     | 24/50 [00:52<00:48,  1.88s/it, epoch=1/5, avg_epoch_loss=3.9]
#  50%|█████     | 25/50 [00:44<00:41,  1.66s/it, epoch=4/5, avg_epoch_loss=1.3]
#  28%|██▊       | 7/25 [00:10<00:28,  1.56s/it, epoch=18/20, avg_epoch_loss=0.818]
#  16%|█▌        | 8/50 [00:11<01:02,  1.48s/it, epoch=4/5, avg_epoch_loss=1.11]
# Running evaluation: 0it [00:00, ?it/s]
#  60%|██████    | 30/50 [00:21<00:14,  1.35it/s, epoch=2/5, avg_epoch_loss=2.25]
#  50%|█████     | 25/50 [00:20<00:20,  1.23it/s, epoch=1/10, avg_epoch_loss=1.57]
#  52%|█████▏    | 26/50 [00:56<00:44,  1.84s/it, epoch=1/5, avg_epoch_loss=3.63]
#  84%|████████▍ | 42/50 [00:31<00:06,  1.33it/s, epoch=2/5, avg_epoch_loss=1.99]
#  28%|██▊       | 7/25 [00:10<00:26,  1.49s/it, epoch=18/20, avg_epoch_loss=1.04]
# Running evaluation: 41922it [00:02, 15786.33it/s]
#  62%|██████▏   | 31/50 [01:02<00:32,  1.72s/it, epoch=1/5, avg_epoch_loss=3.67]
# 100%|██████████| 50/50 [00:38<00:00,  1.28it/s, epoch=2/5, avg_epoch_loss=2.02]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  66%|██████▌   | 33/50 [00:58<00:28,  1.70s/it, epoch=4/5, avg_epoch_loss=1.37]
#  82%|████████▏ | 41/50 [00:31<00:06,  1.37it/s, epoch=1/10, avg_epoch_loss=1.61]
#  86%|████████▌ | 43/50 [00:33<00:05,  1.25it/s, epoch=2/5, avg_epoch_loss=2.08]
#  16%|█▌        | 8/50 [00:26<01:02,  1.48s/it, epoch=4/5, avg_epoch_loss=1.24]
#  62%|██████▏   | 31/50 [01:13<00:32,  1.72s/it, epoch=1/5, avg_epoch_loss=3.71]
#  52%|█████▏    | 26/50 [01:08<00:44,  1.84s/it, epoch=1/5, avg_epoch_loss=3.58]
#  28%|██▊       | 14/50 [00:27<01:13,  2.03s/it, epoch=4/5, avg_epoch_loss=1.27]
#  28%|██▊       | 7/25 [00:23<00:26,  1.49s/it, epoch=18/20, avg_epoch_loss=0.959]
#  28%|██▊       | 7/25 [00:27<00:28,  1.56s/it, epoch=18/20, avg_epoch_loss=0.913]
#  66%|██████▌   | 33/50 [01:09<00:31,  1.87s/it, epoch=1/5, avg_epoch_loss=3.55]
#  74%|███████▍  | 37/50 [01:14<00:23,  1.78s/it, epoch=1/5, avg_epoch_loss=3.69]
#  56%|█████▌    | 14/25 [00:23<00:19,  1.75s/it, epoch=18/20, avg_epoch_loss=0.97]
#  56%|█████▌    | 14/25 [00:30<00:25,  2.33s/it, epoch=18/20, avg_epoch_loss=0.923]
# 100%|██████████| 50/50 [00:38<00:00,  1.30it/s, epoch=1/10, avg_epoch_loss=1.54]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [00:40<00:00,  1.24it/s, epoch=2/5, avg_epoch_loss=1.96]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  22%|██▏       | 11/50 [00:10<00:38,  1.02it/s, epoch=3/5, avg_epoch_loss=1.69]
#  78%|███████▊  | 39/50 [01:09<00:19,  1.74s/it, epoch=4/5, avg_epoch_loss=1.38]
#  86%|████████▌ | 43/50 [01:25<00:12,  1.82s/it, epoch=1/5, avg_epoch_loss=3.67]
#  80%|████████  | 20/25 [00:35<00:09,  1.81s/it, epoch=18/20, avg_epoch_loss=1.01]
#  78%|███████▊  | 39/50 [01:22<00:21,  1.96s/it, epoch=1/5, avg_epoch_loss=3.35]
#  36%|███▌      | 18/50 [00:41<01:21,  2.56s/it, epoch=4/5, avg_epoch_loss=1.32]
# (objectiveFNN pid=715695) /home/reffert/.conda/envs/TEST_ENV/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:1181: UserWarning: Warning: converting a masked element to nan.
# (objectiveFNN pid=715695)   return arr.astype(dtype, copy=True)
#  20%|██        | 10/50 [00:10<00:41,  1.04s/it, epoch=2/10, avg_epoch_loss=1.45]
#  22%|██▏       | 11/50 [00:10<00:38,  1.02it/s, epoch=3/5, avg_epoch_loss=2.07]
#  44%|████▍     | 22/50 [00:21<00:27,  1.03it/s, epoch=3/5, avg_epoch_loss=1.72]
#  72%|███████▏  | 18/25 [00:44<00:18,  2.64s/it, epoch=18/20, avg_epoch_loss=0.896]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  90%|█████████ | 45/50 [01:20<00:08,  1.74s/it, epoch=4/5, avg_epoch_loss=1.33]
# 100%|██████████| 25/25 [00:43<00:00,  1.75s/it, epoch=18/20, avg_epoch_loss=1]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:36<00:00,  1.93s/it, epoch=1/5, avg_epoch_loss=3.44]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  92%|█████████▏| 46/50 [01:32<00:07,  1.79s/it, epoch=1/5, avg_epoch_loss=3.4]
# 100%|██████████| 50/50 [01:26<00:00,  1.72s/it, epoch=4/5, avg_epoch_loss=1.29]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  50%|█████     | 25/50 [00:52<00:52,  2.08s/it, epoch=4/5, avg_epoch_loss=1.26]
#  60%|██████    | 30/50 [00:20<00:13,  1.53it/s, epoch=2/10, avg_epoch_loss=1.37]
#  52%|█████▏    | 26/50 [00:20<00:18,  1.28it/s, epoch=3/5, avg_epoch_loss=1.69]
#  74%|███████▍  | 37/50 [00:31<00:10,  1.24it/s, epoch=3/5, avg_epoch_loss=1.96]
#  26%|██▌       | 13/50 [00:10<00:29,  1.26it/s, epoch=1/10, avg_epoch_loss=1.28]
# 100%|██████████| 25/25 [00:54<00:00,  2.18s/it, epoch=18/20, avg_epoch_loss=0.901]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:39<00:00,  1.98s/it, epoch=1/5, avg_epoch_loss=3.64]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:10<00:22,  1.34s/it, epoch=19/20, avg_epoch_loss=1.12]
#  12%|█▏        | 6/50 [00:10<01:18,  1.78s/it, epoch=2/5, avg_epoch_loss=1.85]
# 100%|██████████| 50/50 [00:29<00:00,  1.71it/s, epoch=2/10, avg_epoch_loss=1.37]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  14%|█▍        | 7/50 [00:10<01:03,  1.48s/it, epoch=5/5, avg_epoch_loss=1.23]
#  64%|██████▍   | 32/50 [01:02<00:33,  1.86s/it, epoch=4/5, avg_epoch_loss=1.26]
# 100%|██████████| 50/50 [00:42<00:00,  1.18it/s, epoch=3/5, avg_epoch_loss=1.87]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  82%|████████▏ | 41/50 [00:32<00:06,  1.30it/s, epoch=3/5, avg_epoch_loss=1.61]
#  54%|█████▍    | 27/50 [00:20<00:17,  1.32it/s, epoch=1/10, avg_epoch_loss=1.47]
#  32%|███▏      | 8/25 [00:11<00:23,  1.38s/it, epoch=19/20, avg_epoch_loss=1.03]
#  14%|█▍        | 7/50 [00:10<01:06,  1.54s/it, epoch=2/5, avg_epoch_loss=2.03]
#  64%|██████▍   | 16/25 [00:21<00:12,  1.35s/it, epoch=19/20, avg_epoch_loss=1.05]
# 100%|██████████| 50/50 [00:38<00:00,  1.30it/s, epoch=3/5, avg_epoch_loss=1.75]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  38%|███▊      | 19/50 [00:10<00:16,  1.90it/s, epoch=3/10, avg_epoch_loss=1.16]
#  28%|██▊       | 14/50 [00:20<00:52,  1.45s/it, epoch=2/5, avg_epoch_loss=2.49]
#  28%|██▊       | 14/50 [00:21<00:56,  1.56s/it, epoch=5/5, avg_epoch_loss=1.25]
#  78%|███████▊  | 39/50 [01:13<00:19,  1.76s/it, epoch=4/5, avg_epoch_loss=1.23]
# 100%|██████████| 50/50 [00:30<00:00,  1.63it/s, epoch=1/10, avg_epoch_loss=1.41]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  30%|███       | 15/50 [00:10<00:25,  1.39it/s, epoch=4/5, avg_epoch_loss=2.3]
#  64%|██████▍   | 16/25 [00:21<00:12,  1.34s/it, epoch=19/20, avg_epoch_loss=1.06]
#  28%|██▊       | 14/50 [00:21<00:56,  1.58s/it, epoch=2/5, avg_epoch_loss=2.46]
#  32%|███▏      | 16/50 [00:10<00:22,  1.54it/s, epoch=4/5, avg_epoch_loss=1.18]
#  78%|███████▊  | 39/50 [00:20<00:05,  1.94it/s, epoch=3/10, avg_epoch_loss=1.32]
#  96%|█████████▌| 24/25 [00:34<00:01,  1.47s/it, epoch=19/20, avg_epoch_loss=1.02]
#  44%|████▍     | 22/50 [00:33<00:41,  1.48s/it, epoch=2/5, avg_epoch_loss=2.22]
# 100%|██████████| 25/25 [00:35<00:00,  1.43s/it, epoch=19/20, avg_epoch_loss=1.01]
#   0%|          | 0/25 [00:00<?, ?it/s]
#  92%|█████████▏| 46/50 [01:24<00:06,  1.66s/it, epoch=4/5, avg_epoch_loss=1.21]
#  42%|████▏     | 21/50 [00:32<00:45,  1.58s/it, epoch=5/5, avg_epoch_loss=1.23]
#  48%|████▊     | 24/50 [00:10<00:11,  2.33it/s, epoch=2/10, avg_epoch_loss=1.1]
#  58%|█████▊    | 29/50 [00:21<00:15,  1.36it/s, epoch=4/5, avg_epoch_loss=1.81]
# 100%|██████████| 50/50 [00:25<00:00,  2.00it/s, epoch=3/10, avg_epoch_loss=1.28]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  96%|█████████▌| 24/25 [00:32<00:01,  1.38s/it, epoch=19/20, avg_epoch_loss=1.04]
# 100%|██████████| 25/25 [00:34<00:00,  1.36s/it, epoch=19/20, avg_epoch_loss=1.03]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:30<00:00,  1.80s/it, epoch=4/5, avg_epoch_loss=1.19]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  44%|████▍     | 22/50 [00:33<00:41,  1.48s/it, epoch=2/5, avg_epoch_loss=2.19]
#  64%|██████▍   | 32/50 [00:21<00:12,  1.49it/s, epoch=4/5, avg_epoch_loss=1.2]
#  60%|██████    | 30/50 [00:44<00:28,  1.44s/it, epoch=2/5, avg_epoch_loss=2.22]
#  32%|███▏      | 8/25 [00:11<00:23,  1.38s/it, epoch=20/20, avg_epoch_loss=0.937]
#  56%|█████▌    | 28/50 [00:44<00:35,  1.60s/it, epoch=5/5, avg_epoch_loss=1.19]
#  96%|█████████▌| 48/50 [00:21<00:00,  2.24it/s, epoch=2/10, avg_epoch_loss=1.16]
#  46%|████▌     | 23/50 [00:10<00:12,  2.17it/s, epoch=4/10, avg_epoch_loss=1.05]
#  90%|█████████ | 45/50 [00:32<00:03,  1.41it/s, epoch=4/5, avg_epoch_loss=1.63]
# 100%|██████████| 50/50 [00:22<00:00,  2.25it/s, epoch=2/10, avg_epoch_loss=1.17]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:10<00:21,  1.28s/it, epoch=20/20, avg_epoch_loss=0.969]
# 100%|██████████| 50/50 [00:35<00:00,  1.42it/s, epoch=4/5, avg_epoch_loss=1.7]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  14%|█▍        | 7/50 [00:10<01:04,  1.50s/it, epoch=5/5, avg_epoch_loss=0.989]
#  62%|██████▏   | 31/50 [00:43<00:25,  1.35s/it, epoch=2/5, avg_epoch_loss=2.01]
#  94%|█████████▍| 47/50 [00:33<00:02,  1.38it/s, epoch=4/5, avg_epoch_loss=1.18]
#  46%|████▌     | 23/50 [00:21<00:12,  2.17it/s, epoch=4/10, avg_epoch_loss=1.23]
#  60%|██████    | 30/50 [00:57<00:28,  1.44s/it, epoch=2/5, avg_epoch_loss=2.11]
#  32%|███▏      | 16/50 [00:10<00:21,  1.57it/s, epoch=3/10, avg_epoch_loss=0.986]
# 100%|██████████| 50/50 [00:36<00:00,  1.35it/s, epoch=4/5, avg_epoch_loss=1.2]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  32%|███▏      | 8/25 [00:23<00:23,  1.38s/it, epoch=20/20, avg_epoch_loss=0.978]
#  70%|███████   | 35/50 [00:56<00:24,  1.63s/it, epoch=5/5, avg_epoch_loss=1.21]
#  80%|████████  | 40/50 [00:22<00:05,  1.72it/s, epoch=4/10, avg_epoch_loss=1.23]
#  64%|██████▍   | 16/25 [00:24<00:14,  1.59s/it, epoch=20/20, avg_epoch_loss=0.972]
#  22%|██▏       | 11/50 [00:10<00:36,  1.07it/s, epoch=5/5, avg_epoch_loss=1.56]
#  76%|███████▌  | 38/50 [01:00<00:20,  1.67s/it, epoch=2/5, avg_epoch_loss=2.09]
#  14%|█▍        | 7/50 [00:26<01:04,  1.50s/it, epoch=5/5, avg_epoch_loss=0.991]
#  62%|██████▏   | 31/50 [00:59<00:25,  1.35s/it, epoch=2/5, avg_epoch_loss=1.96]
#  76%|███████▌  | 38/50 [01:00<00:20,  1.68s/it, epoch=2/5, avg_epoch_loss=1.94]
#  24%|██▍       | 12/50 [00:27<01:32,  2.43s/it, epoch=5/5, avg_epoch_loss=1.01]
#  32%|███▏      | 8/25 [00:29<00:21,  1.28s/it, epoch=20/20, avg_epoch_loss=0.992]
#  70%|███████   | 35/50 [01:06<00:24,  1.63s/it, epoch=5/5, avg_epoch_loss=1.2]
#  18%|█▊        | 9/50 [00:10<00:49,  1.21s/it, epoch=5/5, avg_epoch_loss=1.18]
#  32%|███▏      | 16/50 [00:21<00:21,  1.57it/s, epoch=3/10, avg_epoch_loss=1.09]
#  80%|████████  | 40/50 [01:07<00:18,  1.81s/it, epoch=5/5, avg_epoch_loss=1.2]
#  54%|█████▍    | 27/50 [00:22<00:19,  1.16it/s, epoch=3/10, avg_epoch_loss=1.12]
# 100%|██████████| 50/50 [00:34<00:00,  1.47it/s, epoch=4/10, avg_epoch_loss=1.29]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  60%|██████    | 15/25 [00:32<00:23,  2.33s/it, epoch=20/20, avg_epoch_loss=0.996]
#  88%|████████▊ | 22/25 [00:37<00:05,  1.80s/it, epoch=20/20, avg_epoch_loss=0.934]
#  44%|████▍     | 22/50 [00:22<00:29,  1.04s/it, epoch=5/5, avg_epoch_loss=1.37]
#  86%|████████▌ | 43/50 [01:16<00:14,  2.06s/it, epoch=2/5, avg_epoch_loss=2.11]
#  38%|███▊      | 19/50 [00:20<00:33,  1.08s/it, epoch=5/5, avg_epoch_loss=1.15]
# 100%|██████████| 25/25 [00:44<00:00,  1.78s/it, epoch=20/20, avg_epoch_loss=0.936]
#  32%|███▏      | 16/50 [00:38<01:27,  2.57s/it, epoch=5/5, avg_epoch_loss=1.1]
#  88%|████████▊ | 44/50 [01:11<00:10,  1.75s/it, epoch=2/5, avg_epoch_loss=1.89]
#  82%|████████▏ | 41/50 [00:32<00:07,  1.24it/s, epoch=3/10, avg_epoch_loss=1.22]
#  28%|██▊       | 14/50 [00:10<00:25,  1.39it/s, epoch=5/10, avg_epoch_loss=1.48]
#  92%|█████████▏| 46/50 [01:19<00:07,  1.84s/it, epoch=5/5, avg_epoch_loss=1.2]
#  80%|████████  | 20/25 [00:43<00:11,  2.25s/it, epoch=20/20, avg_epoch_loss=0.987]
#  70%|███████   | 35/50 [00:32<00:13,  1.09it/s, epoch=5/5, avg_epoch_loss=1.23]
# 100%|██████████| 50/50 [00:36<00:00,  1.36it/s, epoch=3/10, avg_epoch_loss=1.18]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:24<00:00,  1.70s/it, epoch=5/5, avg_epoch_loss=1.18]
# 100%|██████████| 50/50 [01:27<00:00,  1.74s/it, epoch=2/5, avg_epoch_loss=2.04]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 50/50 [01:19<00:00,  1.59s/it, epoch=2/5, avg_epoch_loss=1.91]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:49<00:00,  1.99s/it, epoch=20/20, avg_epoch_loss=0.999]
#  66%|██████▌   | 33/50 [00:31<00:15,  1.13it/s, epoch=5/5, avg_epoch_loss=1.13]
#  46%|████▌     | 23/50 [00:49<00:57,  2.11s/it, epoch=5/5, avg_epoch_loss=1.11]
#  78%|███████▊  | 39/50 [00:20<00:05,  2.00it/s, epoch=5/10, avg_epoch_loss=1.33]
#  96%|█████████▌| 48/50 [00:43<00:01,  1.13it/s, epoch=5/5, avg_epoch_loss=1.21]
#  44%|████▍     | 22/50 [00:10<00:13,  2.14it/s, epoch=4/10, avg_epoch_loss=1.05]
# 100%|██████████| 50/50 [00:45<00:00,  1.10it/s, epoch=5/5, avg_epoch_loss=1.19]
# 100%|██████████| 50/50 [00:26<00:00,  1.92it/s, epoch=5/10, avg_epoch_loss=1.32]
#   0%|          | 0/50 [00:00<?, ?it/s]
#  14%|█▍        | 7/50 [00:10<01:05,  1.53s/it, epoch=3/5, avg_epoch_loss=1.37]
#  94%|█████████▍| 47/50 [00:41<00:02,  1.23it/s, epoch=5/5, avg_epoch_loss=1.13]
#  16%|█▌        | 8/50 [00:11<01:01,  1.46s/it, epoch=3/5, avg_epoch_loss=1.16]
# Running evaluation: 0it [00:00, ?it/s]
# 100%|██████████| 50/50 [00:43<00:00,  1.15it/s, epoch=5/5, avg_epoch_loss=1.16]
# Running evaluation: 41922it [00:02, 15233.55it/s]
#  60%|██████    | 30/50 [01:02<00:39,  1.97s/it, epoch=5/5, avg_epoch_loss=1.15]
#  88%|████████▊ | 44/50 [00:22<00:03,  1.97it/s, epoch=4/10, avg_epoch_loss=1.32]
#  40%|████      | 20/50 [00:10<00:15,  1.88it/s, epoch=6/10, avg_epoch_loss=1.1]
# 100%|██████████| 50/50 [00:25<00:00,  1.95it/s, epoch=4/10, avg_epoch_loss=1.4]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Running evaluation: 0it [00:00, ?it/s]
#  30%|███       | 15/50 [00:26<01:03,  1.81s/it, epoch=3/5, avg_epoch_loss=1.33]
#  72%|███████▏  | 36/50 [01:14<00:28,  2.03s/it, epoch=5/5, avg_epoch_loss=1.17]
# Running evaluation: 41922it [00:03, 12348.11it/s]
# Running evaluation: 0it [00:00, ?it/s]
#  40%|████      | 20/50 [00:21<00:15,  1.88it/s, epoch=6/10, avg_epoch_loss=1.21]
#  70%|███████   | 35/50 [00:21<00:09,  1.60it/s, epoch=6/10, avg_epoch_loss=1.22]
#  14%|█▍        | 7/50 [00:30<01:05,  1.53s/it, epoch=3/5, avg_epoch_loss=1.5]
#  18%|█▊        | 9/50 [00:10<00:47,  1.15s/it, epoch=5/10, avg_epoch_loss=1.26]
#  28%|██▊       | 14/50 [00:34<01:33,  2.60s/it, epoch=3/5, avg_epoch_loss=1.46]
# Running evaluation: 41922it [00:08, 5105.42it/s]
#  72%|███████▏  | 36/50 [01:26<00:28,  2.03s/it, epoch=5/5, avg_epoch_loss=1.16]
#  30%|███       | 15/50 [00:40<01:03,  1.81s/it, epoch=3/5, avg_epoch_loss=1.32]
#  36%|███▌      | 18/50 [00:40<01:21,  2.54s/it, epoch=3/5, avg_epoch_loss=1.31]
